# %%
from sequence_distance_matrix import *
from import_data_encoded_knn import *
from sklearn.metrics import log_loss, recall_score, roc_auc_score, precision_score, accuracy_score, mean_squared_error
from math import sqrt
from time import ctime

X_try, X_train, X_test, y_train, y_test, len_X_train = import_data_encoded(encoding = 'binary')

categorical = ['ring_number', "exposure_type", "conc1_type","species",'tripleBond', 'obs_duration_mean', 'doubleBond',
    'alone_atom_number', 'class', 'tax_order', 'family', 'genus', 'oh_count']

non_categorical =[ 'atom_number', 'bonds_number', 'Mol', 'MorganDensity', 'LogP']

# %%
def cv_params_logloss(X,y, categorical, non_categorical, sequence_ham = [],
                  ks = [1], leaf_size = range(60, 91, 10)):

    np.random.seed(123)
    print(ctime())
    print('START...')
    best_accuracy = 0
    best_alpha = 0
    best_k = 0
    best_leaf = 0
    best_log_loss = 100
    
    print('Computing Euclidean ...')
    basic_mat = euclidean_matrix(X, non_categorical)

    for ah in sequence_ham:
        print('\n', ctime())
        print('Adding Hamming 1 (Categorical)... alpha = {}'.format(ah))
        dist_matr = ah * hamming_matrix(X, categorical)
        dist_matr += basic_mat
        dist_matr = pd.DataFrame(dist_matr)
        print(ctime())
        print('Start CV...')
        for k in ks:
            for ls in leaf_size:

                kf = KFold(n_splits=5, shuffle=True)
                accs = []
                rmse = []
                lls = []
                for train_index, test_index in kf.split(dist_matr):

                    X_train = dist_matr.iloc[train_index, train_index]
                    X_test = dist_matr.iloc[test_index, train_index]
                    y_train = y[train_index]
                    y_test = y[test_index]

                    neigh = KNeighborsClassifier(metric = 'precomputed',
                                                 n_neighbors=k, n_jobs=-2,
                                                 leaf_size=ls)
                    neigh.fit(X_train, y_train.ravel())
                    y_pred = neigh.predict(X_test)

                    accs.append(accuracy_score(y_test, y_pred))
                    rmse.append(sqrt(mean_squared_error(y_test, y_pred)))
                    lls.append(log_loss(y_test, neigh.predict_proba(X_test)))
                    
                    
                avg_lls = np.mean(lls)
                
                avg_acc = np.mean(accs)
                se_acc = sem(accs)

                avg_rmse = np.mean(rmse)
                se_rmse = sem(rmse)
                if (avg_lls < best_log_loss):
                    print('''New best params found! alpha:{}, k:{}, leaf:{},
                                                    log_loss:{}, 
                                                    acc:  {}, st.error:  {},
                                                    rmse: {}, st.error:  {}'''.format(ah, k, ls, avg_lls,
                                                                                    avg_acc, se_acc,
                                                                                    avg_rmse, se_rmse))
                    best_alpha = ah
                    best_k = k
                    best_accuracy = avg_acc
                    best_leaf = ls
                    best_log_loss = avg_lls
    
    return best_log_loss, best_accuracy, best_alpha, best_k, best_leaf

# %%
ham = np.logspace(-3, 0, 30) 

best_ll, best_acc, best_alpha, best_k, best_leaf = cv_params_logloss(X_train, y_train, categorical, non_categorical,
                                                    sequence_ham = ham)
# Out:
# Thu Aug 13 17:19:44 2020
# START...
# Computing Euclidean ...
#
#  Thu Aug 13 17:19:50 2020
# Adding Hamming 1 (Categorical)... alpha = 0.001
# Thu Aug 13 17:20:01 2020
# Start CV...
# New best params found! alpha:0.001, k:1, leaf:60,
#                                                     log_loss:3.722451164737895,
#                                                     acc:  0.892224, st.error:  0.0028377343075066145,
#                                                     rmse: 0.3281785813768681, st.error:  0.004324890908055959
# New best params found! alpha:0.001, k:1, leaf:70,
#                                                     log_loss:3.592032745070712,
#                                                     acc:  0.8960000000000001, st.error:  0.0029899030084603053,
#                                                     rmse: 0.3223556085199903, st.error:  0.004659980035010051
# New best params found! alpha:0.001, k:1, leaf:90,
#                                                     log_loss:3.5765593732457917,
#                                                     acc:  0.896448, st.error:  0.0022276229483465114,
#                                                     rmse: 0.3217204420160409, st.error:  0.0034625564617513952
#
#  Thu Aug 13 17:21:07 2020
# Adding Hamming 1 (Categorical)... alpha = 0.0012689610031679222
# Thu Aug 13 17:21:17 2020
# Start CV...
#
#  Thu Aug 13 17:22:24 2020
# Adding Hamming 1 (Categorical)... alpha = 0.0016102620275609393
# Thu Aug 13 17:22:36 2020
# Start CV...
# New best params found! alpha:0.0016102620275609393, k:1, leaf:80,
#                                                     log_loss:3.5677174464886945,
#                                                     acc:  0.8967040000000001, st.error:  0.0025707773143545517,
#                                                     rmse: 0.32129831869949654, st.error:  0.003980904447382238
#
#  Thu Aug 13 17:23:42 2020
# Adding Hamming 1 (Categorical)... alpha = 0.0020433597178569417
# Thu Aug 13 17:23:55 2020
# Start CV...
#
#  Thu Aug 13 17:25:03 2020
# Adding Hamming 1 (Categorical)... alpha = 0.002592943797404667
# Thu Aug 13 17:25:15 2020
# Start CV...
#
#  Thu Aug 13 17:26:21 2020
# Adding Hamming 1 (Categorical)... alpha = 0.0032903445623126675
# Thu Aug 13 17:26:33 2020
# Start CV...
#
#  Thu Aug 13 17:27:39 2020
# Adding Hamming 1 (Categorical)... alpha = 0.0041753189365604
# Thu Aug 13 17:27:50 2020
# Start CV...
#
#  Thu Aug 13 17:28:56 2020
# Adding Hamming 1 (Categorical)... alpha = 0.005298316906283708
# Thu Aug 13 17:29:08 2020
# Start CV...
#
#  Thu Aug 13 17:30:14 2020
# Adding Hamming 1 (Categorical)... alpha = 0.006723357536499335
# Thu Aug 13 17:30:25 2020
# Start CV...
#
#  Thu Aug 13 17:31:32 2020
# Adding Hamming 1 (Categorical)... alpha = 0.008531678524172805
# Thu Aug 13 17:31:43 2020
# Start CV...
#
#  Thu Aug 13 17:32:51 2020
# Adding Hamming 1 (Categorical)... alpha = 0.010826367338740546
# Thu Aug 13 17:33:02 2020
# Start CV...
#
#  Thu Aug 13 17:34:09 2020
# Adding Hamming 1 (Categorical)... alpha = 0.01373823795883263
# Thu Aug 13 17:34:20 2020
# Start CV...
#
#  Thu Aug 13 17:35:27 2020
# Adding Hamming 1 (Categorical)... alpha = 0.017433288221999882
# Thu Aug 13 17:35:38 2020
# Start CV...
#
#  Thu Aug 13 17:36:46 2020
# Adding Hamming 1 (Categorical)... alpha = 0.022122162910704492
# Thu Aug 13 17:36:57 2020
# Start CV...
#
#  Thu Aug 13 17:38:03 2020
# Adding Hamming 1 (Categorical)... alpha = 0.02807216203941177
# Thu Aug 13 17:38:14 2020
# Start CV...
#
#  Thu Aug 13 17:39:22 2020
# Adding Hamming 1 (Categorical)... alpha = 0.035622478902624426
# Thu Aug 13 17:39:33 2020
# Start CV...
#
#  Thu Aug 13 17:40:41 2020
# Adding Hamming 1 (Categorical)... alpha = 0.04520353656360243
# Thu Aug 13 17:40:52 2020
# Start CV...
#
#  Thu Aug 13 17:42:00 2020
# Adding Hamming 1 (Categorical)... alpha = 0.057361525104486784
# Thu Aug 13 17:42:12 2020
# Start CV...
#
#  Thu Aug 13 17:43:21 2020
# Adding Hamming 1 (Categorical)... alpha = 0.0727895384398315
# Thu Aug 13 17:43:32 2020
# Start CV...
#
#  Thu Aug 13 17:44:40 2020
# Adding Hamming 1 (Categorical)... alpha = 0.09236708571873861
# Thu Aug 13 17:44:51 2020
# Start CV...
#
#  Thu Aug 13 17:46:00 2020
# Adding Hamming 1 (Categorical)... alpha = 0.11721022975334805
# Thu Aug 13 17:46:11 2020
# Start CV...
#
#  Thu Aug 13 17:47:19 2020
# Adding Hamming 1 (Categorical)... alpha = 0.14873521072935117
# Thu Aug 13 17:47:30 2020
# Start CV...
#
#  Thu Aug 13 17:48:36 2020
# Adding Hamming 1 (Categorical)... alpha = 0.18873918221350977
# Thu Aug 13 17:48:47 2020
# Start CV...
#
#  Thu Aug 13 17:49:55 2020
# Adding Hamming 1 (Categorical)... alpha = 0.2395026619987486
# Thu Aug 13 17:50:06 2020
# Start CV...
#
#  Thu Aug 13 17:51:11 2020
# Adding Hamming 1 (Categorical)... alpha = 0.3039195382313198
# Thu Aug 13 17:51:23 2020
# Start CV...
#
#  Thu Aug 13 17:52:29 2020
# Adding Hamming 1 (Categorical)... alpha = 0.38566204211634725
# Thu Aug 13 17:52:41 2020
# Start CV...
#
#  Thu Aug 13 17:53:47 2020
# Adding Hamming 1 (Categorical)... alpha = 0.4893900918477494
# Thu Aug 13 17:53:59 2020
# Start CV...
#
#  Thu Aug 13 17:55:03 2020
# Adding Hamming 1 (Categorical)... alpha = 0.6210169418915616
# Thu Aug 13 17:55:15 2020
# Start CV...
#
#  Thu Aug 13 17:56:21 2020
# Adding Hamming 1 (Categorical)... alpha = 0.7880462815669912
# Thu Aug 13 17:56:32 2020
# Start CV...
#
#  Thu Aug 13 17:57:39 2020
# Adding Hamming 1 (Categorical)... alpha = 1.0
# Thu Aug 13 17:57:50 2020
# Start CV...
