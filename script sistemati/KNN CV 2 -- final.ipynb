# %% [markdown]
# # KNN
#
# - **Categorical features**: conc1_type, exposure_type, control_type, media_type, application_freq_unit, class, tax_order, family, genus, species
#
# - **Non Categorical features**: obs_duration_mean, conc1_mean, atom_number, alone_atom_number, bonds_number, doubleBond, tripleBond, ring_number, Mol, MorganDensity, LogP, oh_count
#
# It turns out that *obs_duration_mean* have to be considered as a categorical feature in order to maxime the metrics.

# %%
from helper_knn import *

X_try, X_train, X_test, y_train, y_test, len_X_train = load_data_knn('data/lc_db_processed.csv',
                                                                     encoding = 'binary', seed = 42)

# Best combination
categorical = ['class', 'tax_order', 'family', 'genus', "species", 'control_type', 'media_type',
               'application_freq_unit',"exposure_type", "conc1_type", 'obs_duration_mean']

non_categorical = ['ring_number', 'tripleBond', 'doubleBond', 'alone_atom_number', 'oh_count',
                   'atom_number', 'bonds_number', 'Mol', 'MorganDensity', 'LogP']

# %% [markdown]
# ## BINARY -- K = 1
# ### Finding the best alpha_1 for the problem
#
# START: alpha_1 = 0, alpha_2 = 1, alpha_3 = 0
#
# END: alpha_1 = 0.0069519279617756054, alpha_2 = 1, alpha_3 = 0

# %%
c = [0,0]
ham = np.logspace(-3, -1, 20) 

best_acc, best_alpha, best_k, best_leaf = cv_params_new(X_train, y_train, categorical, non_categorical,
                                                    sequence_ham = ham, choice = c, ks = [1])
# Out:
# Mon Sep 14 11:08:06 2020
# START...
# Computing Euclidean ...
# Adding Hamming 1 (Categorical)... alpha = 0.001
# Start CV...
# New best params found! alpha:0.001, k:1, leaf:10,
#                                                         acc:  0.8976980539183801, st.error:  0.0026286215760152913,
#                                                         rmse: 0.31974227013083456, st.error:  0.004087382206260621
# New best params found! alpha:0.001, k:1, leaf:40,
#                                                         acc:  0.8984766658275387, st.error:  0.0013155183512758776,
#                                                         rmse: 0.3186007056220668, st.error:  0.0020569728718740753
# New best params found! alpha:0.001, k:1, leaf:80,
#                                                         acc:  0.8997000774068564, st.error:  0.001976147553967034,
#                                                         rmse: 0.3166398848354725, st.error:  0.003126736498423271
# Adding Hamming 1 (Categorical)... alpha = 0.0012742749857031334
# Start CV...
# New best params found! alpha:0.0012742749857031334, k:1, leaf:70,
#                                                         acc:  0.8999218359194086, st.error:  0.0021062443613757815,
#                                                         rmse: 0.3162814833729438, st.error:  0.0033236785344627866
# Adding Hamming 1 (Categorical)... alpha = 0.001623776739188721
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.00206913808111479
# Start CV...
# New best params found! alpha:0.00206913808111479, k:1, leaf:30,
#                                                         acc:  0.9000891051974478, st.error:  0.0009774697699740347,
#                                                         rmse: 0.31607168719629675, st.error:  0.0015478497535777608
# Adding Hamming 1 (Categorical)... alpha = 0.0026366508987303583
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.003359818286283781
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.004281332398719396
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.00545559478116852
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.0069519279617756054
# Start CV...
# New best params found! alpha:0.0069519279617756054, k:1, leaf:40,
#                                                         acc:  0.9005335185287351, st.error:  0.0013699253365462001,
#                                                         rmse: 0.31535310273916983, st.error:  0.002173825202470477
# Adding Hamming 1 (Categorical)... alpha = 0.008858667904100823
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.011288378916846888
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.01438449888287663
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.018329807108324356
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.023357214690901212
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.029763514416313176
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.0379269019073225
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.04832930238571752
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.06158482110660261
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.07847599703514611
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.1
# Start CV...
# Mon Sep 14 12:28:07 2020

# %% [markdown]
# ### Finding the best alpha_3, fixing best_alpha_1
# START: alpha_1 = 0.0069519279617756054, alpha_2 = 1, alpha_3 = 0
#
# END: alpha_1 = 0.0069519279617756054, alpha_2 = 1, alpha_3 = 0.0069519279617756054

# %%
c = [0,1]
al_ham = 0.0069519279617756054
pub = np.logspace(-3, -1, 20)

best_acc, best_alpha, best_k, best_leaf = cv_params_new(X_train, y_train, categorical, non_categorical,
                                                    sequence_pub = pub, a_ham = al_ham, choice = c, ks = [1])
# Out:
# Mon Sep 14 12:29:06 2020
# START...
# Computing Basic Matrix: Hamming 1 and Euclidean 2...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.001
# Start CV...
# New best params found! alpha:0.001, k:1, leaf:10,
#                                                         acc:  0.8977536249017346, st.error:  0.002539752081748882,
#                                                         rmse: 0.3196624298760987, st.error:  0.003946708247816731
# New best params found! alpha:0.001, k:1, leaf:40,
#                                                         acc:  0.8985878387013575, st.error:  0.0013189399299914412,
#                                                         rmse: 0.31842614944471437, st.error:  0.0020584368131552197
# New best params found! alpha:0.001, k:1, leaf:80,
#                                                         acc:  0.8998112657342301, st.error:  0.0019271779321472723,
#                                                         rmse: 0.3164673314241388, st.error:  0.0030480488453350613
# Adding Hamming 3 (Pubchem2d)... alpha = 0.0012742749857031334
# Start CV...
# New best params found! alpha:0.0012742749857031334, k:1, leaf:70,
#                                                         acc:  0.9003110491526585, st.error:  0.0020569886189985838,
#                                                         rmse: 0.31566885765906394, st.error:  0.003245117546531897
# Adding Hamming 3 (Pubchem2d)... alpha = 0.001623776739188721
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.00206913808111479
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.0026366508987303583
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.003359818286283781
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.004281332398719396
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.00545559478116852
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.0069519279617756054
# Start CV...
# New best params found! alpha:0.0069519279617756054, k:1, leaf:40,
#                                                         acc:  0.9005335030751802, st.error:  0.0014496678823934408,
#                                                         rmse: 0.31534952732881744, st.error:  0.002300681329046057
# Adding Hamming 3 (Pubchem2d)... alpha = 0.008858667904100823
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.011288378916846888
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.01438449888287663
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.018329807108324356
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.023357214690901212
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.029763514416313176
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.0379269019073225
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.04832930238571752
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.06158482110660261
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.07847599703514611
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.1
# Start CV...
# Mon Sep 14 15:19:24 2020

# %% [markdown]
# ### Finding again the best alpha_1, fixing best_alpha_3
#
# START: alpha_1 = 0.0069519279617756054, alpha_2 = 1, alpha_3 = 0.0069519279617756054
#
# END: alpha_1 = 0.009473684210526315, alpha_2 = 1, alpha_3 = 0.0069519279617756054

# %%
c = [1,0]
al_pub = 0.0069519279617756054

ham = np.linspace(0.005,0.01,20)

best_acc, best_alpha, best_k, best_leaf = cv_params_new(X_train, y_train, categorical, non_categorical,
                                                    sequence_ham = ham, a_pub = al_pub, choice = c, ks = [1])
# Out:
# Mon Sep 14 16:51:44 2020
# START...
# Computing Euclidean and Pubchem2d Matrix...
# Adding Hamming 1 (Categorical)... alpha = 0.005
# Start CV...
# New best params found! alpha:0.005, k:1, leaf:10,
#                                                         acc:  0.8245314057187116, st.error:  0.005742672577797003,
#                                                         rmse: 0.4186730767961923, st.error:  0.006735151210219632
# New best params found! alpha:0.005, k:1, leaf:30,
#                                                         acc:  0.827031914527006, st.error:  0.0024800733461741212,
#                                                         rmse: 0.4158523496638812, st.error:  0.0029541814442851045
# Adding Hamming 1 (Categorical)... alpha = 0.005263157894736842
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.005526315789473685
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.005789473684210527
# Start CV...
# New best params found! alpha:0.005789473684210527, k:1, leaf:30,
#                                                         acc:  0.8277542600428403, st.error:  0.0040559301178579674,
#                                                         rmse: 0.41491049773918875, st.error:  0.004873879947696749
# Adding Hamming 1 (Categorical)... alpha = 0.0060526315789473685
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.00631578947368421
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.006578947368421052
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.006842105263157895
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.007105263157894737
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.007368421052631579
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.0076315789473684215
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.007894736842105263
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.008157894736842105
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.008421052631578947
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.008684210526315789
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.008947368421052631
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.009210526315789475
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.009473684210526315
# Start CV...
# New best params found! alpha:0.009473684210526315, k:1, leaf:30,
#                                                         acc:  0.8284219926957228, st.error:  0.003680484154965518,
#                                                         rmse: 0.4141245864204627, st.error:  0.004439432012037592
# Adding Hamming 1 (Categorical)... alpha = 0.009736842105263158
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.01
# Start CV...
# Mon Sep 14 19:54:54 2020

# %% [markdown]
# ### Finding again the best alpha_3, fixing best_alpha_1
#
# START: alpha_1 = 0.009473684210526315, alpha_2 = 1, alpha_3 = 0.0069519279617756054
#
# END: alpha_1 = 0.009473684210526315, alpha_2 = 1, alpha_3 = 0.007105263157894737

# %%
c = [0,1]
al_ham = 0.009473684210526315
pub = np.linspace(0.005,0.01,20)

best_acc, best_alpha, best_k, best_leaf = cv_params_new(X_train, y_train, categorical, non_categorical,
                                                    sequence_pub = pub, a_ham = al_ham, choice = c, ks = [1])
# Out:
# Mon Sep 14 21:28:13 2020
# START...
# Computing Basic Matrix: Hamming 1 and Euclidean 2...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.005
# Start CV...
# New best params found! alpha:0.005, k:1, leaf:10,
#                                                         acc:  0.8977536249017346, st.error:  0.0025060535258592765,
#                                                         rmse: 0.3196648161329612, st.error:  0.003898090075453123
# New best params found! alpha:0.005, k:1, leaf:40,
#                                                         acc:  0.898532267718003, st.error:  0.0014565415219307638,
#                                                         rmse: 0.3185074989524941, st.error:  0.002275158951814106
# New best params found! alpha:0.005, k:1, leaf:80,
#                                                         acc:  0.899588858172373, st.error:  0.0019329533882988246,
#                                                         rmse: 0.3168182050385376, st.error:  0.0030564188107250296
# Adding Hamming 3 (Pubchem2d)... alpha = 0.005263157894736842
# Start CV...
# New best params found! alpha:0.005263157894736842, k:1, leaf:70,
#                                                         acc:  0.9003110491526585, st.error:  0.0020286124063801972,
#                                                         rmse: 0.31567070885544607, st.error:  0.003199781947329094
# Adding Hamming 3 (Pubchem2d)... alpha = 0.005526315789473685
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.005789473684210527
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.0060526315789473685
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.00631578947368421
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.006578947368421052
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.006842105263157895
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.007105263157894737
# Start CV...
# New best params found! alpha:0.007105263157894737, k:1, leaf:40,
#                                                         acc:  0.900700308746573, st.error:  0.0014967353926612988,
#                                                         rmse: 0.3150827833328018, st.error:  0.002373336295263753
# Adding Hamming 3 (Pubchem2d)... alpha = 0.007368421052631579
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.0076315789473684215
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.007894736842105263
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.008157894736842105
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.008421052631578947
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.008684210526315789
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.008947368421052631
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.009210526315789475
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.009473684210526315
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.009736842105263158
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.01
# Start CV...
# Tue Sep 15 00:20:53 2020

# %% [markdown]
# ## Final model -- BINARY -- K = 1

# %%
y = np.append(y_train,y_test)

del X_train, X_test, y_train, y_test

ham = 0.009473684210526315
pub = 0.007105263157894737
k = 1
leaf = 40

cv_binary_knn(X_try, y, ham, pub, k, leaf)
# Out:
# Basic Matrix... Tue Sep 22 00:23:49 2020
# Adding pubchem2d Tue Sep 22 00:26:50 2020
# End distance matrix... Tue Sep 22 00:40:05 2020
# Accuracy: 	 0.9105265658811724, se: 0.001596093283967252
#     RMSE: 		 0.29907364869243597, se: 0.0026639621159533205
#     Sensitivity: 	 0.9305930270523051, se: 0.0025662688577057476
#     Precision: 	 0.9257884455755866, se: 0.0008814897322470156
#     Specificity: 	 0.877670405685049, se: 0.0016028283693755635

# %% [markdown]
# ## BINARY -- K = 3
# ### Finding the best alpha_1 for the problem
#
# START: alpha_1 = 0, alpha_2 = 1, alpha_3 = 0
#
# END: alpha_1 = 0.008858667904100823, alpha_2 = 1, alpha_3 = 0

# %%
c = [0,0]
ham = np.logspace(-3, -1, 20) 

best_acc, best_alpha, best_k, best_leaf = cv_params_new(X_train, y_train, categorical, non_categorical,
                                                    sequence_ham = ham, choice = c, ks = [3])
# Out:
# Tue Oct  6 15:48:57 2020
# START...
# Computing Euclidean ...
# Adding Hamming 1 (Categorical)... alpha = 0.001
# Start CV...
# New best params found! alpha:0.001, k:3, leaf:10,
#                                                         acc:  0.8865784021426044, st.error:  0.001471987870124243,
#                                                         rmse: 0.33675277506777046, st.error:  0.002188969023942021
# New best params found! alpha:0.001, k:3, leaf:20,
#                                                         acc:  0.887690161787902, st.error:  0.00263278495208526,
#                                                         rmse: 0.335035588524517, st.error:  0.0039048890550307407
# New best params found! alpha:0.001, k:3, leaf:80,
#                                                         acc:  0.8887471076740343, st.error:  0.0023078036127372813,
#                                                         rmse: 0.3334734907055424, st.error:  0.003475748934621125
# Adding Hamming 1 (Categorical)... alpha = 0.0012742749857031334
# Start CV...
# New best params found! alpha:0.0012742749857031334, k:3, leaf:40,
#                                                         acc:  0.889747586270629, st.error:  0.0017462905093825053,
#                                                         rmse: 0.3320016094952075, st.error:  0.0026146233936542294
# Adding Hamming 1 (Categorical)... alpha = 0.001623776739188721
# Start CV...
# New best params found! alpha:0.001623776739188721, k:3, leaf:60,
#                                                         acc:  0.889969746575608, st.error:  0.002160567570211447,
#                                                         rmse: 0.33164473375788395, st.error:  0.003241295846344449
# Adding Hamming 1 (Categorical)... alpha = 0.00206913808111479
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.0026366508987303583
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.003359818286283781
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.004281332398719396
# Start CV...
# New best params found! alpha:0.004281332398719396, k:3, leaf:90,
#                                                         acc:  0.8904705962893233, st.error:  0.0018363362013452658,
#                                                         rmse: 0.33090600588163616, st.error:  0.002766721080054603
# New best params found! alpha:0.004281332398719396, k:3, leaf:100,
#                                                         acc:  0.89097059605752, st.error:  0.002842621083604556,
#                                                         rmse: 0.33008505106631564, st.error:  0.004279690556214526
# Adding Hamming 1 (Categorical)... alpha = 0.00545559478116852
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.0069519279617756054
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.008858667904100823
# Start CV...
# New best params found! alpha:0.008858667904100823, k:3, leaf:80,
#                                                         acc:  0.8914709203503692, st.error:  0.0015179143086536417,
#                                                         rmse: 0.32940533033241587, st.error:  0.002302607121440306
# Adding Hamming 1 (Categorical)... alpha = 0.011288378916846888
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.01438449888287663
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.018329807108324356
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.023357214690901212
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.029763514416313176
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.0379269019073225
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.04832930238571752
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.06158482110660261
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.07847599703514611
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.1
# Start CV...
# Tue Oct  6 17:19:44 2020

# %% [markdown]
# ### Finding the best alpha_3, fixing best_alpha_1
# START: alpha_1 = 0.008858667904100823, alpha_2 = 1, alpha_3 = 0
#
# END: alpha_1 = 0.008858667904100823, alpha_2 = 1, alpha_3 = 0.46415888336127786

# %%
c = [0,1]
al_ham = 0.008858667904100823
pub = np.logspace(-3, -1, 20)

best_acc, best_alpha, best_k, best_leaf = cv_params_new(X_train, y_train, categorical, non_categorical,
                                                    sequence_pub = pub, a_ham = al_ham, choice = c, ks = [3])
# Out:
# Tue Oct  6 17:22:18 2020
# START...
# Computing Basic Matrix: Hamming 1 and Euclidean 2...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.001
# Start CV...
# New best params found! alpha:0.001, k:3, leaf:10,
#                                                         acc:  0.887356735887775, st.error:  0.001693560172563214,
#                                                         rmse: 0.3355857685126894, st.error:  0.0025227011303663215
# New best params found! alpha:0.001, k:3, leaf:20,
#                                                         acc:  0.8884130172710474, st.error:  0.0028595070449058215,
#                                                         rmse: 0.3339387082647631, st.error:  0.004240337587208438
# New best params found! alpha:0.001, k:3, leaf:40,
#                                                         acc:  0.8884132336208157, st.error:  0.0009112003453521156,
#                                                         rmse: 0.33403486224369083, st.error:  0.001367222094492443
# New best params found! alpha:0.001, k:3, leaf:80,
#                                                         acc:  0.8894143458131607, st.error:  0.0023154880686294442,
#                                                         rmse: 0.3324711897664243, st.error:  0.0034843278454257647
# Adding Hamming 3 (Pubchem2d)... alpha = 0.0012742749857031334
# Start CV...
# New best params found! alpha:0.0012742749857031334, k:3, leaf:30,
#                                                         acc:  0.8895253641514307, st.error:  0.002222835606641141,
#                                                         rmse: 0.3323097377879817, st.error:  0.003349403672753142
# New best params found! alpha:0.0012742749857031334, k:3, leaf:40,
#                                                         acc:  0.8905259972835742, st.error:  0.001500124967303466,
#                                                         rmse: 0.33083794829291435, st.error:  0.0022502603049880925
# Adding Hamming 3 (Pubchem2d)... alpha = 0.001623776739188721
# Start CV...
# New best params found! alpha:0.001623776739188721, k:3, leaf:60,
#                                                         acc:  0.8911373708218029, st.error:  0.0023896357204706057,
#                                                         rmse: 0.32986443646884644, st.error:  0.0036084183268891624
# Adding Hamming 3 (Pubchem2d)... alpha = 0.00206913808111479
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.0026366508987303583
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.003359818286283781
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.004281332398719396
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.00545559478116852
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.0069519279617756054
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.008858667904100823
# Start CV...
# New best params found! alpha:0.008858667904100823, k:3, leaf:80,
#                                                         acc:  0.8913597165694407, st.error:  0.0015945023776788492,
#                                                         rmse: 0.32957079037171766, st.error:  0.0024175175449579
# Adding Hamming 3 (Pubchem2d)... alpha = 0.011288378916846888
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.01438449888287663
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.018329807108324356
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.023357214690901212
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.029763514416313176
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.0379269019073225
# Start CV...
# New best params found! alpha:0.0379269019073225, k:3, leaf:60,
#                                                         acc:  0.8915266613228274, st.error:  0.0011359705724080238,
#                                                         rmse: 0.32933508473077067, st.error:  0.001713231051894136
# Adding Hamming 3 (Pubchem2d)... alpha = 0.04832930238571752
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.06158482110660261
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.07847599703514611
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.1
# Start CV...
# New best params found! alpha:0.1, k:3, leaf:80,
#                                                         acc:  0.8915818923279746, st.error:  0.0023555681978735554,
#                                                         rmse: 0.3291904730949008, st.error:  0.0035965294236568407
# Tue Oct  6 20:17:24 2020

# %%
c = [0,1]
al_ham = 0.008858667904100823
pub = np.logspace(-1, 0, 10)

best_acc, best_alpha, best_k, best_leaf = cv_params_new(X_train, y_train, categorical, non_categorical,
                                                    sequence_pub = pub, a_ham = al_ham, choice = c, ks = [3])
# Out:
# Wed Oct  7 01:42:35 2020
# START...
# Computing Basic Matrix: Hamming 1 and Euclidean 2...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.1
# Start CV...
# New best params found! alpha:0.1, k:3, leaf:10,
#                                                         acc:  0.8873567513413299, st.error:  0.0018834664237698242,
#                                                         rmse: 0.3355768450901871, st.error:  0.0028031097903327197
# New best params found! alpha:0.1, k:3, leaf:20,
#                                                         acc:  0.8885241746913113, st.error:  0.0024828809727088235,
#                                                         rmse: 0.3337983135707881, st.error:  0.0036915838737065667
# New best params found! alpha:0.1, k:3, leaf:80,
#                                                         acc:  0.8893030647644578, st.error:  0.0020303205888939084,
#                                                         rmse: 0.3326553078897373, st.error:  0.0030570152243005245
# Adding Hamming 3 (Pubchem2d)... alpha = 0.1291549665014884
# Start CV...
# New best params found! alpha:0.1291549665014884, k:3, leaf:30,
#                                                         acc:  0.8894697313538567, st.error:  0.002028786822248927,
#                                                         rmse: 0.33240452749560967, st.error:  0.0030618110067344977
# New best params found! alpha:0.1291549665014884, k:3, leaf:40,
#                                                         acc:  0.8905260281906837, st.error:  0.001706851939030157,
#                                                         rmse: 0.3308286691580077, st.error:  0.0025672686097119395
# Adding Hamming 3 (Pubchem2d)... alpha = 0.16681005372000587
# Start CV...
# New best params found! alpha:0.16681005372000587, k:3, leaf:60,
#                                                         acc:  0.8911929263516025, st.error:  0.002658028048169995,
#                                                         rmse: 0.3297617142805149, st.error:  0.004008910175265038
# Adding Hamming 3 (Pubchem2d)... alpha = 0.21544346900318834
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.2782559402207124
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.35938136638046275
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.46415888336127786
# Start CV...
# New best params found! alpha:0.46415888336127786, k:3, leaf:90,
#                                                         acc:  0.8923608287617855, st.error:  0.0010010662962719695,
#                                                         rmse: 0.3280698902177032, st.error:  0.0015263003274815642
# Adding Hamming 3 (Pubchem2d)... alpha = 0.5994842503189409
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.774263682681127
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 1.0
# Start CV...
# Wed Oct  7 03:10:54 2020

# %% [markdown]
# ### Finding again the best alpha_1, fixing best_alpha_3
#
# START: alpha_1 = 0.008858667904100823 alpha_2 = 1, alpha_3 = 0.46415888336127786
#
# END: alpha_1 = 0.039331167860186894 alpha_2 = 1, alpha_3 = 0.46415888336127786

# %%
c = [1,0]
al_pub = 0.46415888336127786

ham = np.logspace(-2.1,-1,20)

best_acc, best_alpha, best_k, best_leaf = cv_params_new(X_train, y_train, categorical, non_categorical,
                                                    sequence_ham = ham, a_pub = al_pub, choice = c, ks = [3])
# Out:
# Wed Oct  7 03:15:41 2020
# START...
# Computing Euclidean and Pubchem2d Matrix...
# Adding Hamming 1 (Categorical)... alpha = 0.007943282347242814
# Start CV...
# New best params found! alpha:0.007943282347242814, k:3, leaf:10,
#                                                         acc:  0.8397084346893363, st.error:  0.0024519901755913277,
#                                                         rmse: 0.40031798425955667, st.error:  0.003044535639013152
# New best params found! alpha:0.007943282347242814, k:3, leaf:20,
#                                                         acc:  0.8397638047764774, st.error:  0.003775281248056422,
#                                                         rmse: 0.40018359131489, st.error:  0.004724628711326613
# New best params found! alpha:0.007943282347242814, k:3, leaf:30,
#                                                         acc:  0.8418766920676749, st.error:  0.0017307674019033284,
#                                                         rmse: 0.3976233023060307, st.error:  0.0021804469479959543
# New best params found! alpha:0.007943282347242814, k:3, leaf:40,
#                                                         acc:  0.8425442701850084, st.error:  0.004006501136575829,
#                                                         rmse: 0.39667498197075185, st.error:  0.005115869757315387
# New best params found! alpha:0.007943282347242814, k:3, leaf:50,
#                                                         acc:  0.8434339622466563, st.error:  0.0018452047716270602,
#                                                         rmse: 0.3956565584667316, st.error:  0.0023412334145419354
# New best params found! alpha:0.007943282347242814, k:3, leaf:70,
#                                                         acc:  0.8448794414096238, st.error:  0.00279543903554889,
#                                                         rmse: 0.3937890502221417, st.error:  0.0035616890487406164
# Adding Hamming 1 (Categorical)... alpha = 0.009076005216818141
# Start CV...
# New best params found! alpha:0.009076005216818141, k:3, leaf:100,
#                                                         acc:  0.8459356764322317, st.error:  0.0012947584927727855,
#                                                         rmse: 0.3924963394521125, st.error:  0.0016543189278731968
# Adding Hamming 1 (Categorical)... alpha = 0.010370255908667636
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.011849068510006666
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.01353876180022544
# Start CV...
# New best params found! alpha:0.01353876180022544, k:3, leaf:50,
#                                                         acc:  0.8459912937762507, st.error:  0.000893601488866759,
#                                                         rmse: 0.3924328350089617, st.error:  0.0011375665451129125
# Adding Hamming 1 (Categorical)... alpha = 0.015469407652461993
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.017675366229876723
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.020195897501643797
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.0230758599619549
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.026366508987303583
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.03012640904060446
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.03442247595686089
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.039331167860186894
# Start CV...
# New best params found! alpha:0.039331167860186894, k:3, leaf:20,
#                                                         acc:  0.8475480539879211, st.error:  0.0016703103432396842,
#                                                         rmse: 0.390427698478264, st.error:  0.0021306262603155678
# Adding Hamming 1 (Categorical)... alpha = 0.04493984590721668
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.05134832907437552
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.058670670659931035
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.06703718811765355
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.07659678234751838
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.08751958772041742
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.1
# Start CV...
# Wed Oct  7 06:28:58 2020

# %% [markdown]
# ### Finding again the best alpha_3, fixing best_alpha_1
#
# START: alpha_1 = 0.039331167860186894 alpha_2 = 1, alpha_3 = 0.46415888336127786
#
# END: alpha_1 = 0.039331167860186894 alpha_2 = 1, alpha_3 = 1.0

# %%
c = [0,1]
al_ham = 0.039331167860186894
pub = [i for i in np.logspace(-0.5,0,10)] + [2, 5, 10, 100, 1000, 10000]

best_acc, best_alpha, best_k, best_leaf = cv_params_new(X_train, y_train, categorical, non_categorical,
                                                    sequence_pub = pub, a_ham = al_ham, choice = c, ks = [3])
# Out:
# Wed Oct  7 08:26:54 2020
# START...
# Computing Basic Matrix: Hamming 1 and Euclidean 2...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.31622776601683794
# Start CV...
# New best params found! alpha:0.31622776601683794, k:3, leaf:10,
#                                                         acc:  0.8852439104107972, st.error:  0.002462560687709792,
#                                                         rmse: 0.3386803882723388, st.error:  0.0035945858210874268
# New best params found! alpha:0.31622776601683794, k:3, leaf:20,
#                                                         acc:  0.8883574617412477, st.error:  0.0024829382978401406,
#                                                         rmse: 0.33404849530623315, st.error:  0.003679029844730267
# New best params found! alpha:0.31622776601683794, k:3, leaf:40,
#                                                         acc:  0.8887469685920404, st.error:  0.0011434658687675026,
#                                                         rmse: 0.33352857338579833, st.error:  0.0017118807780945934
# Adding Hamming 3 (Pubchem2d)... alpha = 0.35938136638046275
# Start CV...
# New best params found! alpha:0.35938136638046275, k:3, leaf:40,
#                                                         acc:  0.8902478951099233, st.error:  0.0013645846631249112,
#                                                         rmse: 0.3312630386841363, st.error:  0.002055729300574879
# Adding Hamming 3 (Pubchem2d)... alpha = 0.4084238652674521
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.46415888336127786
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.5274997063702618
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.599484250318941
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.6812920690579612
# Start CV...
# New best params found! alpha:0.6812920690579612, k:3, leaf:90,
#                                                         acc:  0.8921384211999284, st.error:  0.0009959871084912395,
#                                                         rmse: 0.3284088212551295, st.error:  0.0015186278253783323
# Adding Hamming 3 (Pubchem2d)... alpha = 0.774263682681127
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.8799225435691069
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 1.0
# Start CV...
# New best params found! alpha:1.0, k:3, leaf:80,
#                                                         acc:  0.8925828345312157, st.error:  0.002184606199152652,
#                                                         rmse: 0.32767811373025146, st.error:  0.003324877853723231
# Adding Hamming 3 (Pubchem2d)... alpha = 2
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 5
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 10
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 100
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 1000
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 10000
# Start CV...
# Wed Oct  7 10:46:45 2020

# %% [markdown]
# ## Final model -- BINARY -- K = 3

# %%
y = np.append(y_train,y_test)

del X_train, X_test, y_train, y_test

ham = 0.039331167860186894
pub = 1.0
k = 3
leaf = 80

cv_binary_knn(X_try, y, ham, pub, k, leaf)
# Out:
# Basic Matrix... Wed Oct  7 11:52:02 2020
# Adding pubchem2d Wed Oct  7 11:54:39 2020
# End distance matrix... Wed Oct  7 12:10:16 2020
# Accuracy: 	 0.9061686077707287, se: 0.0015416791459042548
#     RMSE: 		 0.3062780121023428, se: 0.0025085619340753074
#     Sensitivity: 	 0.9297288797672791, se: 0.0016272575609664918
#     Precision: 	 0.9200600256244315, se: 0.0018468057727389193
#     Specificity: 	 0.8675772077090196, se: 0.002544648179924816

# %% [markdown]
# ## BINARY -- K = 5
# ### Finding the best alpha_1 for the problem
#
# START: alpha_1 = 0, alpha_2 = 1, alpha_3 = 0
#
# END: alpha_1 = 0.004281332398719396, alpha_2 = 1, alpha_3 = 0

# %%
c = [0,0]
ham = np.logspace(-3, -1, 20) 

best_acc, best_alpha, best_k, best_leaf = cv_params_new(X_train, y_train, categorical, non_categorical,
                                                    sequence_ham = ham, choice = c, ks = [5])
# Out:
# Sun Sep 20 20:36:42 2020
# START...
# Computing Euclidean ...
# Adding Hamming 1 (Categorical)... alpha = 0.001
# Start CV...
# New best params found! alpha:0.001, k:5, leaf:10,
#                                                         acc:  0.8761812967788764, st.error:  0.002418811517636534,
#                                                         rmse: 0.3518115974103475, st.error:  0.0034388642275861754
# New best params found! alpha:0.001, k:5, leaf:20,
#                                                         acc:  0.880184540170975, st.error:  0.002459028612155808,
#                                                         rmse: 0.34607134161526065, st.error:  0.0035385852271274066
# Adding Hamming 1 (Categorical)... alpha = 0.0012742749857031334
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.001623776739188721
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.00206913808111479
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.0026366508987303583
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.003359818286283781
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.004281332398719396
# Start CV...
# New best params found! alpha:0.004281332398719396, k:5, leaf:20,
#                                                         acc:  0.881297180668901, st.error:  0.002919516187998029,
#                                                         rmse: 0.3444312952538767, st.error:  0.00418037620423924
# Adding Hamming 1 (Categorical)... alpha = 0.00545559478116852
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.0069519279617756054
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.008858667904100823
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.011288378916846888
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.01438449888287663
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.018329807108324356
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.023357214690901212
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.029763514416313176
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.0379269019073225
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.04832930238571752
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.06158482110660261
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.07847599703514611
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.1
# Start CV...
# Sun Sep 20 22:01:27 2020

# %% [markdown]
# ### Finding the best alpha_3, fixing best_alpha_1
# START: alpha_1 = 0.004281332398719396, alpha_2 = 1, alpha_3 = 0
#
# END: alpha_1 = 0.004281332398719396, alpha_2 = 1, alpha_3 = 0.0379269019073225

# %%
c = [0,1]
al_ham = 0.004281332398719396
pub = np.logspace(-3, -1, 20)

best_acc, best_alpha, best_k, best_leaf = cv_params_new(X_train, y_train, categorical, non_categorical,
                                                    sequence_pub = pub, a_ham = al_ham, choice = c, ks = [5])
# Out:
# Sun Sep 20 22:23:14 2020
# START...
# Computing Basic Matrix: Hamming 1 and Euclidean 2...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.001
# Start CV...
# New best params found! alpha:0.001, k:5, leaf:10,
#                                                         acc:  0.8766817292466099, st.error:  0.001168452234182648,
#                                                         rmse: 0.3511512650906884, st.error:  0.0016628122713671133
# New best params found! alpha:0.001, k:5, leaf:20,
#                                                         acc:  0.8801288301056266, st.error:  0.0026295035397560017,
#                                                         rmse: 0.34614127610917766, st.error:  0.0037877060301538105
# Adding Hamming 3 (Pubchem2d)... alpha = 0.0012742749857031334
# Start CV...
# New best params found! alpha:0.0012742749857031334, k:5, leaf:40,
#                                                         acc:  0.8804630132299429, st.error:  0.0021034171628869567,
#                                                         rmse: 0.34568860756938846, st.error:  0.0030155168211453676
# Adding Hamming 3 (Pubchem2d)... alpha = 0.001623776739188721
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.00206913808111479
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.0026366508987303583
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.003359818286283781
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.004281332398719396
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.00545559478116852
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.0069519279617756054
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.008858667904100823
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.011288378916846888
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.01438449888287663
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.018329807108324356
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.023357214690901212
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.029763514416313176
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.0379269019073225
# Start CV...
# New best params found! alpha:0.0379269019073225, k:5, leaf:60,
#                                                         acc:  0.8813520098816212, st.error:  0.001244977019351228,
#                                                         rmse: 0.3444341969260974, st.error:  0.0018079066799214561
# Adding Hamming 3 (Pubchem2d)... alpha = 0.04832930238571752
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.06158482110660261
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.07847599703514611
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.1
# Start CV...
# Mon Sep 21 01:21:31 2020

# %% [markdown]
# ### Finding again the best alpha_1, fixing best_alpha_3
#
# START: alpha_1 = 0.004281332398719396, alpha_2 = 1, alpha_3 = 0.0379269019073225
#
# END: alpha_1 = 0.014399033208816327 alpha_2 = 1, alpha_3 = 0.0379269019073225

# %%
c = [1,0]
al_pub = 0.0379269019073225

ham = np.logspace(-2.8,-1.8,25)

best_acc, best_alpha, best_k, best_leaf = cv_params_new(X_train, y_train, categorical, non_categorical,
                                                    sequence_ham = ham, a_pub = al_pub, choice = c, ks = [5])
# Out:
# Mon Sep 21 05:45:16 2020
# START...
# Computing Euclidean and Pubchem2d Matrix...
# Adding Hamming 1 (Categorical)... alpha = 0.001584893192461114
# Start CV...
# New best params found! alpha:0.001584893192461114, k:5, leaf:10,
#                                                         acc:  0.8432674347392515, st.error:  0.002852271713141206,
#                                                         rmse: 0.395829532552304, st.error:  0.0035897917827189354
# Adding Hamming 1 (Categorical)... alpha = 0.0017444826989992542
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.001920141938638803
# Start CV...
# New best params found! alpha:0.001920141938638803, k:5, leaf:30,
#                                                         acc:  0.8442678824287364, st.error:  0.0014235023780417933,
#                                                         rmse: 0.39461252835898064, st.error:  0.001807625057665591
# Adding Hamming 1 (Categorical)... alpha = 0.0021134890398366475
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.0023263050671536263
# Start CV...
# New best params found! alpha:0.0023263050671536263, k:5, leaf:70,
#                                                         acc:  0.8442680987785046, st.error:  0.0032857896754917796,
#                                                         rmse: 0.3945414946488794, st.error:  0.00415060904337029
# Adding Hamming 1 (Categorical)... alpha = 0.002560550427970478
# Start CV...
# New best params found! alpha:0.002560550427970478, k:5, leaf:10,
#                                                         acc:  0.8472135772460623, st.error:  0.004607518473719703,
#                                                         rmse: 0.3906966417635861, st.error:  0.005969859055997247
# Adding Hamming 1 (Categorical)... alpha = 0.002818382931264455
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.0031021776647995013
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.003414548873833601
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.003758374042884443
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.004136820402388507
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.004553374104426249
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.005011872336272725
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.00551653866759558
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.006072021956909884
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.006683439175686149
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.007356422544596414
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.008097171416105617
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.008912509381337459
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.009809947127268775
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.010797751623277094
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.011885022274370183
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.013081774742601943
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.014399033208816327
# Start CV...
# New best params found! alpha:0.014399033208816327, k:5, leaf:100,
#                                                         acc:  0.8474368965676572, st.error:  0.002964914171555721,
#                                                         rmse: 0.390519767314153, st.error:  0.0037886267051042955
# Adding Hamming 1 (Categorical)... alpha = 0.015848931924611134
# Start CV...
# Mon Sep 21 09:48:18 2020

# %% [markdown]
# ### Finding again the best alpha_3, fixing best_alpha_1
#
# START: alpha_1 = 0.014399033208816327, alpha_2 = 1, alpha_3 = 0.0379269019073225
#
# END: alpha_1 = 0.014399033208816327, alpha_2 = 1, alpha_3 = ------------

# %%
c = [0,1]
al_ham = 0.014399033208816327
pub = [i for i in np.logspace(-1.6, 0, 10)] + [1.5, 2, 10, 100, 1000, 10000]

best_acc, best_alpha, best_k, best_leaf = cv_params_new(X_train, y_train, categorical, non_categorical,
                                                    sequence_pub = pub, a_ham = al_ham, choice = c, ks = [5])
# Out:
# Thu Oct  8 18:20:50 2020
# START...
# Computing Basic Matrix: Hamming 1 and Euclidean 2...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.025118864315095794
# Start CV...
# New best params found! alpha:0.025118864315095794, k:5, leaf:10,
#                                                         acc:  0.8766260346348164, st.error:  0.001960253171965585,
#                                                         rmse: 0.35120252648395944, st.error:  0.0027726682305826912
# New best params found! alpha:0.025118864315095794, k:5, leaf:20,
#                                                         acc:  0.8797953887519446, st.error:  0.0018286467562533342,
#                                                         rmse: 0.34666477285905994, st.error:  0.002652664068051391
# New best params found! alpha:0.025118864315095794, k:5, leaf:90,
#                                                         acc:  0.8804070250006065, st.error:  0.002108237217088025,
#                                                         rmse: 0.34576863932197427, st.error:  0.003042328911537419
# Adding Hamming 3 (Pubchem2d)... alpha = 0.037824899063893844
# Start CV...
# New best params found! alpha:0.037824899063893844, k:5, leaf:100,
#                                                         acc:  0.8805739852075481, st.error:  0.00207290716259004,
#                                                         rmse: 0.34552834341231337, st.error:  0.0030074362501249174
# Adding Hamming 3 (Pubchem2d)... alpha = 0.056958108107376865
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.08576958985908938
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.12915496650148836
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.1944862438937362
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.29286445646252357
# Start CV...
# New best params found! alpha:0.29286445646252357, k:5, leaf:20,
#                                                         acc:  0.8805743251857556, st.error:  0.002995584602538446,
#                                                         rmse: 0.34547178576006476, st.error:  0.004327818676779562
# New best params found! alpha:0.29286445646252357, k:5, leaf:70,
#                                                         acc:  0.8817409758579929, st.error:  0.0029122394054474894,
#                                                         rmse: 0.3437844139537712, st.error:  0.004221991960826739
# Adding Hamming 3 (Pubchem2d)... alpha = 0.44100594541767363
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.6640827850634842
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 1.0
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 1.5
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 2
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 10
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 100
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 1000
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 10000
# Start CV...
# New best params found! alpha:10000, k:5, leaf:70,
#                                                         acc:  0.8822976592654956, st.error:  0.002277411643851493,
#                                                         rmse: 0.3430135750995381, st.error:  0.003317681115549348
# Thu Oct  8 20:44:41 2020

# %%
c = [0,1]
al_ham = 0.014399033208816327
pub = [10000, 15000, 20000, 50000]

best_acc, best_alpha, best_k, best_leaf = cv_params_new(X_train, y_train, categorical, non_categorical,
                                                    sequence_pub = pub, a_ham = al_ham, choice = c, ks = [5])
# Out:
# Thu Oct  8 22:47:07 2020
# START...
# Computing Basic Matrix: Hamming 1 and Euclidean 2...
# Adding Hamming 3 (Pubchem2d)... alpha = 10000
# Start CV...
# New best params found! alpha:10000, k:5, leaf:10,
#                                                         acc:  0.8769600786771387, st.error:  0.0025048288125693085,
#                                                         rmse: 0.35069609225411275, st.error:  0.0036115163213070265
# New best params found! alpha:10000, k:5, leaf:20,
#                                                         acc:  0.877904970836824, st.error:  0.0015625853321730662,
#                                                         rmse: 0.3493925767344551, st.error:  0.002228030858963717
# New best params found! alpha:10000, k:5, leaf:30,
#                                                         acc:  0.8782941377094092, st.error:  0.0027283227168917188,
#                                                         rmse: 0.3487764869553651, st.error:  0.003899501175305083
# New best params found! alpha:10000, k:5, leaf:60,
#                                                         acc:  0.8785165143641566, st.error:  0.0023815567226263424,
#                                                         rmse: 0.34847675259760047, st.error:  0.0034437818918392547
# New best params found! alpha:10000, k:5, leaf:70,
#                                                         acc:  0.8787391228222271, st.error:  0.0018284671764564765,
#                                                         rmse: 0.34818482711954196, st.error:  0.0026553409153808175
# New best params found! alpha:10000, k:5, leaf:80,
#                                                         acc:  0.8790176113347498, st.error:  0.0031677166500983806,
#                                                         rmse: 0.3477074782248462, st.error:  0.004524882644011869
# New best params found! alpha:10000, k:5, leaf:90,
#                                                         acc:  0.8799621944233375, st.error:  0.0025636960165590153,
#                                                         rmse: 0.3463861296963965, st.error:  0.0036896724317260097
# Adding Hamming 3 (Pubchem2d)... alpha = 15000
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 20000
# Start CV...
# New best params found! alpha:20000, k:5, leaf:60,
#                                                         acc:  0.8800176572318078, st.error:  0.0025230282033879654,
#                                                         rmse: 0.34630788496265796, st.error:  0.0036466279246260397
# Adding Hamming 3 (Pubchem2d)... alpha = 50000
# Start CV...
# New best params found! alpha:50000, k:5, leaf:30,
#                                                         acc:  0.8802958984874524, st.error:  0.0017620297293225635,
#                                                         rmse: 0.3459450135585148, st.error:  0.0025568098553969765
# New best params found! alpha:50000, k:5, leaf:40,
#                                                         acc:  0.8810741704184034, st.error:  0.0017678906536973177,
#                                                         rmse: 0.34481844940181333, st.error:  0.0025527697568337097
# Thu Oct  8 23:23:53 2020

# %%
c = [0,1]
al_ham = 0.014399033208816327
pub = [50000, 1000000, 10000000]

best_acc, best_alpha, best_k, best_leaf = cv_params_new(X_train, y_train, categorical, non_categorical,
                                                    sequence_pub = pub, a_ham = al_ham, choice = c, ks = [5])
# Out:
# Thu Oct  8 23:24:31 2020
# START...
# Computing Basic Matrix: Hamming 1 and Euclidean 2...
# Adding Hamming 3 (Pubchem2d)... alpha = 50000
# Start CV...
# New best params found! alpha:50000, k:5, leaf:10,
#                                                         acc:  0.8769600786771387, st.error:  0.0025048288125693085,
#                                                         rmse: 0.35069609225411275, st.error:  0.0036115163213070265
# New best params found! alpha:50000, k:5, leaf:20,
#                                                         acc:  0.877904970836824, st.error:  0.0015625853321730662,
#                                                         rmse: 0.3493925767344551, st.error:  0.002228030858963717
# New best params found! alpha:50000, k:5, leaf:30,
#                                                         acc:  0.8782941377094092, st.error:  0.0027283227168917188,
#                                                         rmse: 0.3487764869553651, st.error:  0.003899501175305083
# New best params found! alpha:50000, k:5, leaf:60,
#                                                         acc:  0.8785165143641566, st.error:  0.0023815567226263424,
#                                                         rmse: 0.34847675259760047, st.error:  0.0034437818918392547
# New best params found! alpha:50000, k:5, leaf:70,
#                                                         acc:  0.8787391228222271, st.error:  0.0018284671764564765,
#                                                         rmse: 0.34818482711954196, st.error:  0.0026553409153808175
# New best params found! alpha:50000, k:5, leaf:80,
#                                                         acc:  0.8790176113347498, st.error:  0.0031677166500983806,
#                                                         rmse: 0.3477074782248462, st.error:  0.004524882644011869
# New best params found! alpha:50000, k:5, leaf:90,
#                                                         acc:  0.8799621944233375, st.error:  0.0025636960165590153,
#                                                         rmse: 0.3463861296963965, st.error:  0.0036896724317260097
# Adding Hamming 3 (Pubchem2d)... alpha = 1000000
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 10000000
# Start CV...
# New best params found! alpha:10000000, k:5, leaf:60,
#                                                         acc:  0.8800176572318078, st.error:  0.0025230282033879654,
#                                                         rmse: 0.34630788496265796, st.error:  0.0036466279246260397
# Thu Oct  8 23:51:12 2020

# %% [markdown]
# ## Final model -- BINARY -- K = 5

# %%
y = np.append(y_train,y_test)

del X_train, X_test, y_train, y_test

ham = 0.014399033208816327
pub = 10000000
k = 5
leaf = 60

cv_binary_knn(X_try, y, ham, pub, k, leaf)
# Out:
# Basic Matrix... Fri Oct  9 00:05:03 2020
# Adding pubchem2d Fri Oct  9 00:07:29 2020
# End distance matrix... Fri Oct  9 00:20:12 2020
# Accuracy: 	 0.8959994908352071, se: 0.001252572763477651
#     RMSE: 		 0.32246776985430203, se: 0.0019394954231536168
#     Sensitivity: 	 0.9253063556786623, se: 0.002118546423226795
#     Precision: 	 0.908949372669675, se: 0.0028363743015283986
#     Specificity: 	 0.8480611908545651, se: 0.004270880015664068

# %% [markdown]
# # KNN -- MULTICLASS

# %%
from helper_knn import *

X_try, X_train, X_test, y_train, y_test, len_X_train = load_data_knn('data/lc_db_processed.csv',
                                                                     encoding = 'multiclass', seed = 42)

# Best combination
categorical = ['class', 'tax_order', 'family', 'genus', "species", 'control_type', 'media_type',
               'application_freq_unit',"exposure_type", "conc1_type", 'obs_duration_mean']

non_categorical = ['ring_number', 'tripleBond', 'doubleBond', 'alone_atom_number', 'oh_count',
                   'atom_number', 'bonds_number', 'Mol', 'MorganDensity', 'LogP']

# %% [markdown]
# ## MULTICLASS -- K = 1
# ### Finding the best alpha_1 for the problem
#
# START: alpha_1 = 0, alpha_2 = 1, alpha_3 = 0
#
# END: alpha_1 = 0.023357214690901212, alpha_2 = 1, alpha_3 = 0

# %%
c = [0,0]
ham = np.logspace(-3, -1, 20) 

best_acc, best_alpha, best_k, best_leaf = cv_params_new(X_train, y_train, categorical, non_categorical,
                                                    sequence_ham = ham, choice = c, ks = [1])
# Out:
# Tue Sep 22 22:41:52 2020
# START...
# Computing Euclidean ...
# Adding Hamming 1 (Categorical)... alpha = 0.001
# Start CV...
# New best params found! alpha:0.001, k:1, leaf:10,
#                                                         acc:  0.7255086885294288, st.error:  0.003222136760733884,
#                                                         rmse: 0.7183435526109299, st.error:  0.007361166388361987
# New best params found! alpha:0.001, k:1, leaf:20,
#                                                         acc:  0.7255637340919174, st.error:  0.003546667786245106,
#                                                         rmse: 0.7304215945475012, st.error:  0.005548520794540555
# New best params found! alpha:0.001, k:1, leaf:80,
#                                                         acc:  0.7267881501523026, st.error:  0.0033562206883952293,
#                                                         rmse: 0.712964330967776, st.error:  0.005733241624523589
# Adding Hamming 1 (Categorical)... alpha = 0.0012742749857031334
# Start CV...
# New best params found! alpha:0.0012742749857031334, k:1, leaf:70,
#                                                         acc:  0.7288998938804385, st.error:  0.002460920019084405,
#                                                         rmse: 0.7119476371324118, st.error:  0.01017548985943311
# Adding Hamming 1 (Categorical)... alpha = 0.001623776739188721
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.00206913808111479
# Start CV...
# New best params found! alpha:0.00206913808111479, k:1, leaf:30,
#                                                         acc:  0.7289564075306408, st.error:  0.003233664602021161,
#                                                         rmse: 0.719217868739711, st.error:  0.004258384395043181
# Adding Hamming 1 (Categorical)... alpha = 0.0026366508987303583
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.003359818286283781
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.004281332398719396
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.00545559478116852
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.0069519279617756054
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.008858667904100823
# Start CV...
# New best params found! alpha:0.008858667904100823, k:1, leaf:100,
#                                                         acc:  0.7294569481732583, st.error:  0.004450288731962076,
#                                                         rmse: 0.7147018329704657, st.error:  0.008926098797546751
# Adding Hamming 1 (Categorical)... alpha = 0.011288378916846888
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.01438449888287663
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.018329807108324356
# Start CV...
# New best params found! alpha:0.018329807108324356, k:1, leaf:60,
#                                                         acc:  0.7295116228504297, st.error:  0.0033944031223457523,
#                                                         rmse: 0.7158767989789677, st.error:  0.00461057629420791
# Adding Hamming 1 (Categorical)... alpha = 0.023357214690901212
# Start CV...
# New best params found! alpha:0.023357214690901212, k:1, leaf:100,
#                                                         acc:  0.7299565152419184, st.error:  0.0036940870117079146,
#                                                         rmse: 0.7124987234002036, st.error:  0.0056846731776787705
# Adding Hamming 1 (Categorical)... alpha = 0.029763514416313176
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.0379269019073225
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.04832930238571752
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.06158482110660261
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.07847599703514611
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.1
# Start CV...
# Wed Sep 23 00:10:17 2020

# %% [markdown]
# ### Finding the best alpha_3, fixing best_alpha_1
# START: alpha_1 = 0.023357214690901212, alpha_2 = 1, alpha_3 = 0
#
# END1: alpha_1 = 0.023357214690901212, alpha_2 = 1, alpha_3 = 0.1
#
# END2: alpha_1 = 0.023357214690901212, alpha_2 = 1, alpha_3 = 0.4832930238571752

# %%
c = [0,1]
al_ham = 0.023357214690901212
pub = np.logspace(-3, -1, 20)

best_acc, best_alpha, best_k, best_leaf = cv_params_new(X_train, y_train, categorical, non_categorical,
                                                    sequence_pub = pub, a_ham = al_ham, choice = c, ks = [1])
# Out:
# Wed Sep 23 00:19:31 2020
# START...
# Computing Basic Matrix: Hamming 1 and Euclidean 2...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.001
# Start CV...
# New best params found! alpha:0.001, k:1, leaf:10,
#                                                         acc:  0.7256198304961379, st.error:  0.0029769940217011497,
#                                                         rmse: 0.7185721631305062, st.error:  0.007447037493213675
# New best params found! alpha:0.001, k:1, leaf:80,
#                                                         acc:  0.7263988596512782, st.error:  0.002992036837334821,
#                                                         rmse: 0.7144185271959385, st.error:  0.0053160126795970515
# Adding Hamming 3 (Pubchem2d)... alpha = 0.0012742749857031334
# Start CV...
# New best params found! alpha:0.0012742749857031334, k:1, leaf:10,
#                                                         acc:  0.7265092289402431, st.error:  0.0037610557038928872,
#                                                         rmse: 0.719989053054658, st.error:  0.004287650661991828
# New best params found! alpha:0.0012742749857031334, k:1, leaf:60,
#                                                         acc:  0.7268425003048213, st.error:  0.0034542100403032994,
#                                                         rmse: 0.7233890868997787, st.error:  0.007541619455406006
# New best params found! alpha:0.0012742749857031334, k:1, leaf:70,
#                                                         acc:  0.7281214674139388, st.error:  0.002206469409551935,
#                                                         rmse: 0.7126522928374567, st.error:  0.00686906787631719
# Adding Hamming 3 (Pubchem2d)... alpha = 0.001623776739188721
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.00206913808111479
# Start CV...
# New best params found! alpha:0.00206913808111479, k:1, leaf:30,
#                                                         acc:  0.7285671942973909, st.error:  0.003008300380882799,
#                                                         rmse: 0.7205298430471705, st.error:  0.0043104356695224015
# Adding Hamming 3 (Pubchem2d)... alpha = 0.0026366508987303583
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.003359818286283781
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.004281332398719396
# Start CV...
# New best params found! alpha:0.004281332398719396, k:1, leaf:90,
#                                                         acc:  0.7287887210066197, st.error:  0.0044796246337222454,
#                                                         rmse: 0.7142999941411792, st.error:  0.005407760222830426
# Adding Hamming 3 (Pubchem2d)... alpha = 0.00545559478116852
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.0069519279617756054
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.008858667904100823
# Start CV...
# New best params found! alpha:0.008858667904100823, k:1, leaf:100,
#                                                         acc:  0.7290678122077828, st.error:  0.004581316603378875,
#                                                         rmse: 0.7137662748318565, st.error:  0.008952990996940977
# Adding Hamming 3 (Pubchem2d)... alpha = 0.011288378916846888
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.01438449888287663
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.018329807108324356
# Start CV...
# New best params found! alpha:0.018329807108324356, k:1, leaf:20,
#                                                         acc:  0.729178954174492, st.error:  0.0035181635038411424,
#                                                         rmse: 0.7183389144653297, st.error:  0.0064615236116180585
# New best params found! alpha:0.018329807108324356, k:1, leaf:60,
#                                                         acc:  0.729344801725482, st.error:  0.00336010049292778,
#                                                         rmse: 0.7171634314954713, st.error:  0.004362090552378612
# Adding Hamming 3 (Pubchem2d)... alpha = 0.023357214690901212
# Start CV...
# New best params found! alpha:0.023357214690901212, k:1, leaf:100,
#                                                         acc:  0.7303457284751683, st.error:  0.003707687601945597,
#                                                         rmse: 0.7116824067740191, st.error:  0.005574099475081629
# Adding Hamming 3 (Pubchem2d)... alpha = 0.029763514416313176
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.0379269019073225
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.04832930238571752
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.06158482110660261
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.07847599703514611
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.1
# Start CV...
# New best params found! alpha:0.1, k:1, leaf:30,
#                                                         acc:  0.7304012067371936, st.error:  0.0031478907815696753,
#                                                         rmse: 0.704411707895183, st.error:  0.004460711737739823
# Wed Sep 23 03:16:48 2020

# %% [markdown]
# This code chunck has to be re-runned since it point out as optimal value the last value of the interval I set.

# %%
c = [0,1]
al_ham = 0.023357214690901212
pub = np.logspace(-1, 0, 20)

best_acc, best_alpha, best_k, best_leaf = cv_params_new(X_train, y_train, categorical, non_categorical,
                                                    sequence_pub = pub, a_ham = al_ham, choice = c, ks = [1])
# Out:
# Wed Sep 23 18:47:16 2020
# START...
# Computing Basic Matrix: Hamming 1 and Euclidean 2...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.1
# Start CV...
# New best params found! alpha:0.1, k:1, leaf:10,
#                                                         acc:  0.7261202475103163, st.error:  0.0030563025397978205,
#                                                         rmse: 0.7166110159073625, st.error:  0.007088816416174572
# New best params found! alpha:0.1, k:1, leaf:80,
#                                                         acc:  0.7271772397571133, st.error:  0.0028711383187119827,
#                                                         rmse: 0.7123628431239972, st.error:  0.004992303580564422
# Adding Hamming 3 (Pubchem2d)... alpha = 0.11288378916846889
# Start CV...
# New best params found! alpha:0.11288378916846889, k:1, leaf:10,
#                                                         acc:  0.7278992143876304, st.error:  0.0035340244286078725,
#                                                         rmse: 0.7172754828984295, st.error:  0.004520879753682142
# New best params found! alpha:0.11288378916846889, k:1, leaf:60,
#                                                         acc:  0.7279545690212167, st.error:  0.003009956572842989,
#                                                         rmse: 0.7228220205828356, st.error:  0.0073025789089511935
# New best params found! alpha:0.11288378916846889, k:1, leaf:70,
#                                                         acc:  0.7293447244577077, st.error:  0.0019282803980413298,
#                                                         rmse: 0.7108390241244285, st.error:  0.007284445552426858
# Adding Hamming 3 (Pubchem2d)... alpha = 0.12742749857031338
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.14384498882876628
# Start CV...
# New best params found! alpha:0.14384498882876628, k:1, leaf:30,
#                                                         acc:  0.7294567627305999, st.error:  0.0031403643857056246,
#                                                         rmse: 0.7199105069632845, st.error:  0.004386353730937806
# Adding Hamming 3 (Pubchem2d)... alpha = 0.16237767391887217
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.18329807108324356
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.20691380811147897
# Start CV...
# New best params found! alpha:0.20691380811147897, k:1, leaf:50,
#                                                         acc:  0.7301791546070987, st.error:  0.0020642908758583423,
#                                                         rmse: 0.722055362722857, st.error:  0.008107117669744314
# New best params found! alpha:0.20691380811147897, k:1, leaf:90,
#                                                         acc:  0.7306234597635018, st.error:  0.004937368743253945,
#                                                         rmse: 0.7115232116832199, st.error:  0.0056713859725772055
# Adding Hamming 3 (Pubchem2d)... alpha = 0.23357214690901226
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.26366508987303583
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.29763514416313175
# Start CV...
# New best params found! alpha:0.29763514416313175, k:1, leaf:100,
#                                                         acc:  0.7306801434028077, st.error:  0.004197946045623484,
#                                                         rmse: 0.7127263576095068, st.error:  0.007868016906726071
# Adding Hamming 3 (Pubchem2d)... alpha = 0.33598182862837817
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.37926901907322497
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.42813323987193935
# Start CV...
# New best params found! alpha:0.42813323987193935, k:1, leaf:20,
#                                                         acc:  0.7312360077719018, st.error:  0.003026948429407457,
#                                                         rmse: 0.7152884784350737, st.error:  0.0071331008434929715
# New best params found! alpha:0.42813323987193935, k:1, leaf:60,
#                                                         acc:  0.7316243865131882, st.error:  0.003163905780575239,
#                                                         rmse: 0.7106510706953139, st.error:  0.002920483193266359
# Adding Hamming 3 (Pubchem2d)... alpha = 0.4832930238571752
# Start CV...
# New best params found! alpha:0.4832930238571752, k:1, leaf:100,
#                                                         acc:  0.7322915937452045, st.error:  0.003859427816246327,
#                                                         rmse: 0.7062989787956891, st.error:  0.007945989621735147
# Adding Hamming 3 (Pubchem2d)... alpha = 0.5455594781168519
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.6158482110660264
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.6951927961775606
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.7847599703514611
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.8858667904100825
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 1.0
# Start CV...
# Wed Sep 23 21:40:37 2020

# %% [markdown]
# ### Finding again the best alpha_1, fixing best_alpha_3
#
# START: alpha_1 = 0.023357214690901212, alpha_2 = 1, alpha_3 = 0.4832930238571752
#
# END1: alpha_1 = 1.0 alpha_2 = 1, alpha_3 = 0.4832930238571752
#
# END2: alpha_1 = 2.7825594022071245 alpha_2 = 1, alpha_3 = 0.4832930238571752

# %%
c = [1,0]
al_pub = 0.4832930238571752

ham = np.logspace(-2, 0, 20)

best_acc, best_alpha, best_k, best_leaf = cv_params_new(X_train, y_train, categorical, non_categorical,
                                                    sequence_ham = ham, a_pub = al_pub, choice = c, ks = [1])
# Out:
# Wed Sep 23 21:58:04 2020
# START...
# Computing Euclidean and Pubchem2d Matrix...
# Adding Hamming 1 (Categorical)... alpha = 0.01
# Start CV...
# New best params found! alpha:0.01, k:1, leaf:10,
#                                                         acc:  0.5677197800711883, st.error:  0.004939900535676926,
#                                                         rmse: 0.9412787952512911, st.error:  0.005629515686018252
# New best params found! alpha:0.01, k:1, leaf:30,
#                                                         acc:  0.5720558930354382, st.error:  0.0034541145096843974,
#                                                         rmse: 0.9381895946210109, st.error:  0.009681609567517947
# New best params found! alpha:0.01, k:1, leaf:70,
#                                                         acc:  0.5722778833513135, st.error:  0.004358228071446643,
#                                                         rmse: 0.9318040691222567, st.error:  0.007922290370031204
# Adding Hamming 1 (Categorical)... alpha = 0.012742749857031334
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.016237767391887217
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.0206913808111479
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.026366508987303583
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.03359818286283781
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.04281332398719394
# Start CV...
# New best params found! alpha:0.04281332398719394, k:1, leaf:20,
#                                                         acc:  0.5739465736609919, st.error:  0.006315639071124733,
#                                                         rmse: 0.9381645807024949, st.error:  0.01092431852908925
# New best params found! alpha:0.04281332398719394, k:1, leaf:60,
#                                                         acc:  0.5740017273983646, st.error:  0.004522246966057628,
#                                                         rmse: 0.9320382654973377, st.error:  0.008012660411762148
# Adding Hamming 1 (Categorical)... alpha = 0.0545559478116852
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.06951927961775606
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.08858667904100823
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.11288378916846889
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.14384498882876628
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.18329807108324356
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.23357214690901212
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.29763514416313175
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.37926901907322497
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.4832930238571752
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.615848211066026
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.7847599703514611
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 1.0
# Start CV...
# New best params found! alpha:1.0, k:1, leaf:30,
#                                                         acc:  0.5774486119076131, st.error:  0.00547523840517905,
#                                                         rmse: 0.9330907575939854, st.error:  0.008638875297173576
# Thu Sep 24 01:21:07 2020

# %%
c = [1,0]
al_pub = 0.4832930238571752

ham = np.logspace(0, 0.5, 10)

best_acc, best_alpha, best_k, best_leaf = cv_params_new(X_train, y_train, categorical, non_categorical,
                                                    sequence_ham = ham, a_pub = al_pub, choice = c, ks = [1])
# Out:
# Thu Sep 24 05:47:44 2020
# START...
# Computing Euclidean and Pubchem2d Matrix...
# Adding Hamming 1 (Categorical)... alpha = 1.0
# Start CV...
# New best params found! alpha:1.0, k:1, leaf:10,
#                                                         acc:  0.5684981756305785, st.error:  0.004777699496653579,
#                                                         rmse: 0.9419881118866616, st.error:  0.004197384066548152
# New best params found! alpha:1.0, k:1, leaf:30,
#                                                         acc:  0.572500615437823, st.error:  0.004151861528614078,
#                                                         rmse: 0.9365807775990893, st.error:  0.01054366643876818
# Adding Hamming 1 (Categorical)... alpha = 1.1364636663857248
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 1.2915496650148839
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 1.4677992676220695
# Start CV...
# New best params found! alpha:1.4677992676220695, k:1, leaf:70,
#                                                         acc:  0.5726114483334346, st.error:  0.005261846880698041,
#                                                         rmse: 0.9449875111253203, st.error:  0.009504582528403301
# Adding Hamming 1 (Categorical)... alpha = 1.6681005372000588
# Start CV...
# New best params found! alpha:1.6681005372000588, k:1, leaf:60,
#                                                         acc:  0.5732232236640904, st.error:  0.00361203327800261,
#                                                         rmse: 0.9369328440382588, st.error:  0.00926088338787649
# Adding Hamming 1 (Categorical)... alpha = 1.8957356524063758
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 2.154434690031884
# Start CV...
# New best params found! alpha:2.154434690031884, k:1, leaf:20,
#                                                         acc:  0.5736128541433221, st.error:  0.006573090082181294,
#                                                         rmse: 0.9376790963651305, st.error:  0.011773159105814689
# New best params found! alpha:2.154434690031884, k:1, leaf:60,
#                                                         acc:  0.5741128075508543, st.error:  0.004504732289817065,
#                                                         rmse: 0.9341099618759348, st.error:  0.006546575148979964
# Adding Hamming 1 (Categorical)... alpha = 2.448436746822227
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 2.7825594022071245
# Start CV...
# New best params found! alpha:2.7825594022071245, k:1, leaf:30,
#                                                         acc:  0.574168733965971, st.error:  0.0041189386644743965,
#                                                         rmse: 0.9437915221146957, st.error:  0.009925964868280348
# Adding Hamming 1 (Categorical)... alpha = 3.1622776601683795
# Start CV...
# Thu Sep 24 07:26:16 2020

# %% [markdown]
# ### Finding again the best alpha_3, fixing best_alpha_1
#
# START: alpha_1 = 2.7825594022071245, alpha_2 = 1, alpha_3 = 0.4832930238571752
#
# END: alpha_1 = 2.7825594022071245, alpha_2 = 1, alpha_3 = 1000

# %%
c = [0,1]
al_ham = 2.7825594022071245
pub = np.logspace(-0.3, 1, 20)

best_acc, best_alpha, best_k, best_leaf = cv_params_new(X_train, y_train, categorical, non_categorical,
                                                    sequence_pub = pub, a_ham = al_ham, choice = c, ks = [1])
# Out:
# Thu Sep 24 10:42:25 2020
# START...
# Computing Basic Matrix: Hamming 1 and Euclidean 2...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.5011872336272722
# Start CV...
# New best params found! alpha:0.5011872336272722, k:1, leaf:10,
#                                                         acc:  0.5185697951306776, st.error:  0.0012606025896634678,
#                                                         rmse: 1.134684458293093, st.error:  0.009055758374491591
# New best params found! alpha:0.5011872336272722, k:1, leaf:20,
#                                                         acc:  0.5198486077042462, st.error:  0.0035048587031914543,
#                                                         rmse: 1.128338364279855, st.error:  0.003999009126531808
# New best params found! alpha:0.5011872336272722, k:1, leaf:30,
#                                                         acc:  0.5207386861047661, st.error:  0.0024258905741088616,
#                                                         rmse: 1.1294544083579245, st.error:  0.0062501103411609134
# New best params found! alpha:0.5011872336272722, k:1, leaf:70,
#                                                         acc:  0.5226841804894853, st.error:  0.0016112323972191595,
#                                                         rmse: 1.131808284115411, st.error:  0.00391494460076899
# Adding Hamming 3 (Pubchem2d)... alpha = 0.5867067065993101
# Start CV...
# New best params found! alpha:0.5867067065993101, k:1, leaf:10,
#                                                         acc:  0.5235184251962176, st.error:  0.0033978417564967107,
#                                                         rmse: 1.1253600087225597, st.error:  0.00510191944718185
# New best params found! alpha:0.5867067065993101, k:1, leaf:20,
#                                                         acc:  0.5247418367755354, st.error:  0.0034071004970650303,
#                                                         rmse: 1.1202420682006333, st.error:  0.004720054709183879
# New best params found! alpha:0.5867067065993101, k:1, leaf:60,
#                                                         acc:  0.526465479926373, st.error:  0.0026945925662473264,
#                                                         rmse: 1.123624879673665, st.error:  0.0038572354452046
# Adding Hamming 3 (Pubchem2d)... alpha = 0.6868186906464688
# Start CV...
# New best params found! alpha:0.6868186906464688, k:1, leaf:10,
#                                                         acc:  0.5288001720907871, st.error:  0.0027424315272789198,
#                                                         rmse: 1.1065824255569583, st.error:  0.004827506092914447
# New best params found! alpha:0.6868186906464688, k:1, leaf:30,
#                                                         acc:  0.5296896787097765, st.error:  0.0008140433880685331,
#                                                         rmse: 1.117569744245023, st.error:  0.005465816850740191
# New best params found! alpha:0.6868186906464688, k:1, leaf:50,
#                                                         acc:  0.5307459291859391, st.error:  0.0028380648595958025,
#                                                         rmse: 1.1083796162748905, st.error:  0.007559428457991653
# New best params found! alpha:0.6868186906464688, k:1, leaf:100,
#                                                         acc:  0.5336373356649657, st.error:  0.00306394984915393,
#                                                         rmse: 1.1055193848924254, st.error:  0.011178499252576857
# Adding Hamming 3 (Pubchem2d)... alpha = 0.8040131611167856
# Start CV...
# New best params found! alpha:0.8040131611167856, k:1, leaf:30,
#                                                         acc:  0.5338596350519387, st.error:  0.003054721326790635,
#                                                         rmse: 1.1112295203051172, st.error:  0.010096295853097343
# New best params found! alpha:0.8040131611167856, k:1, leaf:100,
#                                                         acc:  0.5339705761224343, st.error:  0.0027368952149390206,
#                                                         rmse: 1.1052392024371849, st.error:  0.008480109112713508
# Adding Hamming 3 (Pubchem2d)... alpha = 0.9412049672680668
# Start CV...
# New best params found! alpha:0.9412049672680668, k:1, leaf:10,
#                                                         acc:  0.5383078017426356, st.error:  0.0018407635772494442,
#                                                         rmse: 1.105631514213989, st.error:  0.006995120799038502
# New best params found! alpha:0.9412049672680668, k:1, leaf:20,
#                                                         acc:  0.5395304251906544, st.error:  0.0027096417995145167,
#                                                         rmse: 1.0974327618261717, st.error:  0.007821198108348899
# New best params found! alpha:0.9412049672680668, k:1, leaf:30,
#                                                         acc:  0.5403087280287152, st.error:  0.0038744836141320995,
#                                                         rmse: 1.10241167518403, st.error:  0.008690595024621146
# New best params found! alpha:0.9412049672680668, k:1, leaf:80,
#                                                         acc:  0.5417540526561339, st.error:  0.004370296711852462,
#                                                         rmse: 1.0944128881648565, st.error:  0.007898604991290092
# Adding Hamming 3 (Pubchem2d)... alpha = 1.1018063301098222
# Start CV...
# New best params found! alpha:1.1018063301098222, k:1, leaf:10,
#                                                         acc:  0.5418667863389957, st.error:  0.005949395195867391,
#                                                         rmse: 1.0986744192903608, st.error:  0.01078501731767318
# New best params found! alpha:1.1018063301098222, k:1, leaf:20,
#                                                         acc:  0.5469250130157566, st.error:  0.0022689779234061095,
#                                                         rmse: 1.0960599197872454, st.error:  0.004695191944975956
# New best params found! alpha:1.1018063301098222, k:1, leaf:30,
#                                                         acc:  0.5479813871203584, st.error:  0.003029876083192854,
#                                                         rmse: 1.085681641130289, st.error:  0.008209626442241137
# Adding Hamming 3 (Pubchem2d)... alpha = 1.2898117108261276
# Start CV...
# New best params found! alpha:1.2898117108261276, k:1, leaf:10,
#                                                         acc:  0.5513731333457889, st.error:  0.0033647739877289895,
#                                                         rmse: 1.0774339376911877, st.error:  0.004870777851039951
# New best params found! alpha:1.2898117108261276, k:1, leaf:20,
#                                                         acc:  0.5522067135496614, st.error:  0.0048521593132545,
#                                                         rmse: 1.07275322399131, st.error:  0.007199699596582795
# New best params found! alpha:1.2898117108261276, k:1, leaf:70,
#                                                         acc:  0.553041066431278, st.error:  0.005113948129650445,
#                                                         rmse: 1.0898961755461503, st.error:  0.010469384981283567
# New best params found! alpha:1.2898117108261276, k:1, leaf:80,
#                                                         acc:  0.5583228133258477, st.error:  0.003929229222351489,
#                                                         rmse: 1.0722274966116037, st.error:  0.008341450138209213
# Adding Hamming 3 (Pubchem2d)... alpha = 1.50989716061842
# Start CV...
# New best params found! alpha:1.50989716061842, k:1, leaf:10,
#                                                         acc:  0.561047460494146, st.error:  0.0025105893175689283,
#                                                         rmse: 1.0585205142386371, st.error:  0.007773073475019676
# New best params found! alpha:1.50989716061842, k:1, leaf:100,
#                                                         acc:  0.5611021197177625, st.error:  0.00650121844781241,
#                                                         rmse: 1.0627477539984287, st.error:  0.01630321522754922
# Adding Hamming 3 (Pubchem2d)... alpha = 1.767536622987673
# Start CV...
# New best params found! alpha:1.767536622987673, k:1, leaf:10,
#                                                         acc:  0.5667740070588748, st.error:  0.0024814909386639138,
#                                                         rmse: 1.0662405790407656, st.error:  0.009337438643036945
# New best params found! alpha:1.767536622987673, k:1, leaf:20,
#                                                         acc:  0.5688306897709674, st.error:  0.0029063209284844785,
#                                                         rmse: 1.048098498192307, st.error:  0.008540549678760436
# New best params found! alpha:1.767536622987673, k:1, leaf:40,
#                                                         acc:  0.5702763698301485, st.error:  0.0035864981171653708,
#                                                         rmse: 1.0427903908696359, st.error:  0.007319886720854343
# Adding Hamming 3 (Pubchem2d)... alpha = 2.0691380811147897
# Start CV...
# New best params found! alpha:2.0691380811147897, k:1, leaf:10,
#                                                         acc:  0.5735020521548205, st.error:  0.0034060010489398588,
#                                                         rmse: 1.0433529809312274, st.error:  0.0031266080738515754
# New best params found! alpha:2.0691380811147897, k:1, leaf:20,
#                                                         acc:  0.5752257416663229, st.error:  0.0036523946258349383,
#                                                         rmse: 1.0355130913939288, st.error:  0.006258853304420787
# New best params found! alpha:2.0691380811147897, k:1, leaf:40,
#                                                         acc:  0.577170432466188, st.error:  0.0037252515256708707,
#                                                         rmse: 1.0296898612884913, st.error:  0.004032620148872688
# Adding Hamming 3 (Pubchem2d)... alpha = 2.4222029365833704
# Start CV...
# New best params found! alpha:2.4222029365833704, k:1, leaf:20,
#                                                         acc:  0.5805624877627162, st.error:  0.004241777296851792,
#                                                         rmse: 1.0320786007095832, st.error:  0.007985695810909129
# New best params found! alpha:2.4222029365833704, k:1, leaf:40,
#                                                         acc:  0.5826752668790295, st.error:  0.0030483375659123416,
#                                                         rmse: 1.0241516550077834, st.error:  0.007182424169728665
# New best params found! alpha:2.4222029365833704, k:1, leaf:60,
#                                                         acc:  0.5833984623403821, st.error:  0.0022471344378429473,
#                                                         rmse: 1.027464881301984, st.error:  0.0058046547251818705
# Adding Hamming 3 (Pubchem2d)... alpha = 2.8355125834966515
# Start CV...
# New best params found! alpha:2.8355125834966515, k:1, leaf:10,
#                                                         acc:  0.5843436172105004, st.error:  0.0025764071292876164,
#                                                         rmse: 1.0203752407704925, st.error:  0.0028724755304139725
# New best params found! alpha:2.8355125834966515, k:1, leaf:20,
#                                                         acc:  0.5889030958570102, st.error:  0.0036114484006380784,
#                                                         rmse: 1.0151864417757537, st.error:  0.008757370849605161
# Adding Hamming 3 (Pubchem2d)... alpha = 3.319346818441578
# Start CV...
# New best params found! alpha:3.319346818441578, k:1, leaf:10,
#                                                         acc:  0.5939624197361676, st.error:  0.002900497411815042,
#                                                         rmse: 1.0064568296981218, st.error:  0.0064074865351735726
# New best params found! alpha:3.319346818441578, k:1, leaf:20,
#                                                         acc:  0.5955748900131865, st.error:  0.003213947416004213,
#                                                         rmse: 1.0036248807424124, st.error:  0.010753095865695955
# New best params found! alpha:3.319346818441578, k:1, leaf:50,
#                                                         acc:  0.596074920688493, st.error:  0.004786907491832407,
#                                                         rmse: 0.9974487299318614, st.error:  0.00958824641526196
# New best params found! alpha:3.319346818441578, k:1, leaf:60,
#                                                         acc:  0.5979093349207224, st.error:  0.0017169600367667956,
#                                                         rmse: 1.0001932706738554, st.error:  0.006504303452526003
# New best params found! alpha:3.319346818441578, k:1, leaf:80,
#                                                         acc:  0.59896560085044, st.error:  0.0017210602414254857,
#                                                         rmse: 0.9896372339601026, st.error:  0.00819443439943152
# Adding Hamming 3 (Pubchem2d)... alpha = 3.885739518570976
# Start CV...
# New best params found! alpha:3.885739518570976, k:1, leaf:10,
#                                                         acc:  0.6039689828609258, st.error:  0.0036072874267361944,
#                                                         rmse: 0.9943241886502092, st.error:  0.007998902445373667
# Adding Hamming 3 (Pubchem2d)... alpha = 4.548777947003778
# Start CV...
# New best params found! alpha:4.548777947003778, k:1, leaf:10,
#                                                         acc:  0.6089185710468688, st.error:  0.002546128059473999,
#                                                         rmse: 0.9787432468863801, st.error:  0.00455103054189793
# New best params found! alpha:4.548777947003778, k:1, leaf:20,
#                                                         acc:  0.6159789448405448, st.error:  0.005312267146838828,
#                                                         rmse: 0.9629798307765188, st.error:  0.003814324579104235
# New best params found! alpha:4.548777947003778, k:1, leaf:50,
#                                                         acc:  0.6179803965474904, st.error:  0.005057611176814147,
#                                                         rmse: 0.9674604147456947, st.error:  0.009447431006050864
# Adding Hamming 3 (Pubchem2d)... alpha = 5.324953129837532
# Start CV...
# New best params found! alpha:5.324953129837532, k:1, leaf:10,
#                                                         acc:  0.6193154137001636, st.error:  0.002979678560875746,
#                                                         rmse: 0.9662357929702283, st.error:  0.007507492781390854
# New best params found! alpha:5.324953129837532, k:1, leaf:20,
#                                                         acc:  0.6194262620493298, st.error:  0.001065593200474666,
#                                                         rmse: 0.9614393173943864, st.error:  0.002211409981105007
# New best params found! alpha:5.324953129837532, k:1, leaf:60,
#                                                         acc:  0.6198709380910502, st.error:  0.0027385331186490264,
#                                                         rmse: 0.9622809520449371, st.error:  0.005582222179381008
# Adding Hamming 3 (Pubchem2d)... alpha = 6.233570019315557
# Start CV...
# New best params found! alpha:6.233570019315557, k:1, leaf:10,
#                                                         acc:  0.6228733783619015, st.error:  0.003345079419443913,
#                                                         rmse: 0.9440035004252444, st.error:  0.006343598928076672
# New best params found! alpha:6.233570019315557, k:1, leaf:20,
#                                                         acc:  0.6245415123436043, st.error:  0.0022663782642776526,
#                                                         rmse: 0.9483451992906197, st.error:  0.009915985401350868
# New best params found! alpha:6.233570019315557, k:1, leaf:30,
#                                                         acc:  0.627321606866818, st.error:  0.005260028880384352,
#                                                         rmse: 0.9435542599804354, st.error:  0.006648106009605501
# New best params found! alpha:6.233570019315557, k:1, leaf:80,
#                                                         acc:  0.628433181069457, st.error:  0.0026747037369526934,
#                                                         rmse: 0.9459819934827995, st.error:  0.004761881945364701
# Adding Hamming 3 (Pubchem2d)... alpha = 7.297227644686393
# Start CV...
# New best params found! alpha:7.297227644686393, k:1, leaf:20,
#                                                         acc:  0.6318250509233267, st.error:  0.003144500029685537,
#                                                         rmse: 0.9334032957167342, st.error:  0.008981436605725911
# New best params found! alpha:7.297227644686393, k:1, leaf:30,
#                                                         acc:  0.6328247722957322, st.error:  0.004429609538339608,
#                                                         rmse: 0.9301073902476468, st.error:  0.00779031401464186
# New best params found! alpha:7.297227644686393, k:1, leaf:40,
#                                                         acc:  0.6331036316935721, st.error:  0.0024971361411862568,
#                                                         rmse: 0.9383216508263216, st.error:  0.008518692385873845
# New best params found! alpha:7.297227644686393, k:1, leaf:80,
#                                                         acc:  0.6332145109498482, st.error:  0.0010677757354207716,
#                                                         rmse: 0.934478936324464, st.error:  0.006128673465494806
# New best params found! alpha:7.297227644686393, k:1, leaf:100,
#                                                         acc:  0.6356617204473557, st.error:  0.004500587831748523,
#                                                         rmse: 0.9289761420295564, st.error:  0.005438730128599562
# Adding Hamming 3 (Pubchem2d)... alpha = 8.542381193020125
# Start CV...
# New best params found! alpha:8.542381193020125, k:1, leaf:10,
#                                                         acc:  0.6406644534085365, st.error:  0.0030531278503760032,
#                                                         rmse: 0.9171483881380137, st.error:  0.009776262061810592
# New best params found! alpha:8.542381193020125, k:1, leaf:30,
#                                                         acc:  0.6417208120595833, st.error:  0.0034289265601187223,
#                                                         rmse: 0.911298938549246, st.error:  0.010076021085818681
# New best params found! alpha:8.542381193020125, k:1, leaf:90,
#                                                         acc:  0.6425548558701024, st.error:  0.002524918841717236,
#                                                         rmse: 0.9126931456209819, st.error:  0.010238231796010008
# Adding Hamming 3 (Pubchem2d)... alpha = 10.0
# Start CV...
# New best params found! alpha:10.0, k:1, leaf:10,
#                                                         acc:  0.6509504168055555, st.error:  0.003438470087986567,
#                                                         rmse: 0.9009027184519492, st.error:  0.008395243073914548
# New best params found! alpha:10.0, k:1, leaf:30,
#                                                         acc:  0.6528966684144637, st.error:  0.0010774528027763948,
#                                                         rmse: 0.8815760393959398, st.error:  0.006161759435999353
# Thu Sep 24 13:39:03 2020

# %%
c = [0,1]
al_ham = 2.7825594022071245
pub = [10,20,50,100]

best_acc, best_alpha, best_k, best_leaf = cv_params_new(X_train, y_train, categorical, non_categorical,
                                                    sequence_pub = pub, a_ham = al_ham, choice = c, ks = [1])
# Out:
# Thu Sep 24 14:06:04 2020
# START...
# Computing Basic Matrix: Hamming 1 and Euclidean 2...
# Adding Hamming 3 (Pubchem2d)... alpha = 10
# Start CV...
# New best params found! alpha:10, k:1, leaf:10,
#                                                         acc:  0.649060107065319, st.error:  0.0039927701073128275,
#                                                         rmse: 0.8970446052192381, st.error:  0.0073117770855754185
# New best params found! alpha:10, k:1, leaf:70,
#                                                         acc:  0.6510060186960198, st.error:  0.004674900141749234,
#                                                         rmse: 0.8892442255135233, st.error:  0.007892436048516993
# Adding Hamming 3 (Pubchem2d)... alpha = 20
# Start CV...
# New best params found! alpha:20, k:1, leaf:10,
#                                                         acc:  0.6760811268361334, st.error:  0.004958342546751918,
#                                                         rmse: 0.8471052725774729, st.error:  0.0058738456135745114
# New best params found! alpha:20, k:1, leaf:40,
#                                                         acc:  0.6770825326460211, st.error:  0.004296965580236755,
#                                                         rmse: 0.8444877824706303, st.error:  0.010631236374326614
# New best params found! alpha:20, k:1, leaf:70,
#                                                         acc:  0.6783609743342724, st.error:  0.000923716511411736,
#                                                         rmse: 0.8386295373553958, st.error:  0.004464091942834998
# Adding Hamming 3 (Pubchem2d)... alpha = 50
# Start CV...
# New best params found! alpha:50, k:1, leaf:10,
#                                                         acc:  0.7003222220728379, st.error:  0.0020613186505383644,
#                                                         rmse: 0.7759417401528234, st.error:  0.005105057040852113
# New best params found! alpha:50, k:1, leaf:30,
#                                                         acc:  0.7012120532164797, st.error:  0.0012002024230742107,
#                                                         rmse: 0.7837886351434595, st.error:  0.008136076545270184
# New best params found! alpha:50, k:1, leaf:60,
#                                                         acc:  0.70321355128409, st.error:  0.0010353736829203568,
#                                                         rmse: 0.7759756958043484, st.error:  0.005230287395124115
# Adding Hamming 3 (Pubchem2d)... alpha = 100
# Start CV...
# New best params found! alpha:100, k:1, leaf:10,
#                                                         acc:  0.71500068845587, st.error:  0.0018791959933197756,
#                                                         rmse: 0.7506398451438742, st.error:  0.005989298719687053
# New best params found! alpha:100, k:1, leaf:30,
#                                                         acc:  0.717892048574232, st.error:  0.0025216855605806935,
#                                                         rmse: 0.7500280882333838, st.error:  0.00541711145718578
# Thu Sep 24 14:41:00 2020

# %%
c = [0,1]
al_ham = 2.7825594022071245
pub = [100,200,500,1000,10000]

best_acc, best_alpha, best_k, best_leaf = cv_params_new(X_train, y_train, categorical, non_categorical,
                                                    sequence_pub = pub, a_ham = al_ham, choice = c, ks = [1])
# Out:
# Mon Sep 28 10:52:21 2020
# START...
# Computing Basic Matrix: Hamming 1 and Euclidean 2...
# Adding Hamming 3 (Pubchem2d)... alpha = 100
# Start CV...
# New best params found! alpha:100, k:1, leaf:10,
#                                                         acc:  0.7155011363771583, st.error:  0.004299724377315707,
#                                                         rmse: 0.7488069810593526, st.error:  0.006479600703800599
# New best params found! alpha:100, k:1, leaf:70,
#                                                         acc:  0.7164458121870751, st.error:  0.003889738274597874,
#                                                         rmse: 0.7470222994556968, st.error:  0.006509207008171904
# Adding Hamming 3 (Pubchem2d)... alpha = 200
# Start CV...
# New best params found! alpha:200, k:1, leaf:10,
#                                                         acc:  0.7252861882462425, st.error:  0.00456556607363394,
#                                                         rmse: 0.7321440495009776, st.error:  0.005083121569278426
# New best params found! alpha:200, k:1, leaf:40,
#                                                         acc:  0.7261761584718783, st.error:  0.003576048454151926,
#                                                         rmse: 0.7256723805972214, st.error:  0.00878142795684114
# New best params found! alpha:200, k:1, leaf:60,
#                                                         acc:  0.7285108042756276, st.error:  0.0021191863913654027,
#                                                         rmse: 0.7200128752061736, st.error:  0.004913755967821235
# Adding Hamming 3 (Pubchem2d)... alpha = 500
# Start CV...
# New best params found! alpha:500, k:1, leaf:60,
#                                                         acc:  0.7286777026683499, st.error:  0.0023568802176871387,
#                                                         rmse: 0.716820652355471, st.error:  0.004148067892387651
# Adding Hamming 3 (Pubchem2d)... alpha = 1000
# Start CV...
# New best params found! alpha:1000, k:1, leaf:30,
#                                                         acc:  0.7312360541325664, st.error:  0.0038467881311582213,
#                                                         rmse: 0.7183455553737279, st.error:  0.005084099503395694
# Adding Hamming 3 (Pubchem2d)... alpha = 10000
# Start CV...
# Mon Sep 28 11:37:35 2020

# %% [markdown]
# ### Finding again the best alpha_1, fixing best_alpha_3
#
# START: alpha_1 = 2.7825594022071245, alpha_2 = 1, alpha_3 = 1000
#
# END: alpha_1 = 2.7825594022071245, alpha_2 = 1, alpha_3 = 1000

# %%
c = [1,0]
al_pub = 1000

ham = [3, 5, 10, 100, 1000]

best_acc, best_alpha, best_k, best_leaf = cv_params_new(X_train, y_train, categorical, non_categorical,
                                                    sequence_ham = ham, a_pub = al_pub, choice = c, ks = [1])
# Out:
# Mon Sep 28 12:53:59 2020
# START...
# Computing Euclidean and Pubchem2d Matrix...
# Adding Hamming 1 (Categorical)... alpha = 3
# Start CV...
# New best params found! alpha:3, k:1, leaf:10,
#                                                         acc:  0.5694989169376061, st.error:  0.005365420350894578,
#                                                         rmse: 0.9437098797254124, st.error:  0.0050949059820642835
# New best params found! alpha:3, k:1, leaf:30,
#                                                         acc:  0.5725560782462934, st.error:  0.0043481487470328015,
#                                                         rmse: 0.9380019223084393, st.error:  0.011840056503234513
# New best params found! alpha:3, k:1, leaf:70,
#                                                         acc:  0.5731674672380773, st.error:  0.004254024042303233,
#                                                         rmse: 0.936920913571455, st.error:  0.007937711609441634
# Adding Hamming 1 (Categorical)... alpha = 5
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 10
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 100
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 1000
# Start CV...
# Mon Sep 28 13:46:17 2020

# %% [markdown]
# ## Final model -- MULTICLASS -- K = 1

# %%
y = np.append(y_train,y_test)

del X_train, X_test, y_train, y_test

ham = 2.7825594022071245
pub = 100
k = 1
leaf = 30

cv_multiclass_knn(X_try, y, ham, pub, k, leaf)
# Out:
# Basic Matrix... Thu Sep 24 15:37:29 2020
# Adding pubchem2d Thu Sep 24 15:40:59 2020
# End distance matrix... Thu Sep 24 15:53:58 2020
# Accuracy: 	 0.7397005500575238, se: 0.0018383759458390201
# RMSE: 		 0.6947909402973472, se: 0.00219610172761468

# %%
y = np.append(y_train,y_test)

del X_train, X_test, y_train, y_test

ham = 2.7825594022071245
pub = 1000
k = 1
leaf = 30

cv_multiclass_knn(X_try, y, ham, pub, k, leaf)
# Out:
# Basic Matrix... Thu Oct  8 17:31:16 2020
# Adding pubchem2d Thu Oct  8 17:33:28 2020
# End distance matrix... Thu Oct  8 17:45:41 2020
# Accuracy: 	 0.7559785276743899, se: 0.0028283453879600776
# RMSE: 		 0.6547477665180885, se: 0.005520359369533257
# W. Recall: 	 0.7559785276743899, se:0.0028283453879600776
# W. Precision: 	 0.7564643020670653, se: 0.0030486937987545958

# %% [markdown]
# ## MULTICLASS -- K = 3
# ### Finding the best alpha_1 for the problem
#
# START: alpha_1 = 0, alpha_2 = 1, alpha_3 = 0
#
# END: alpha_1 = 0.00206913808111479, alpha_2 = 1, alpha_3 = 0

# %%
c = [0,0]
ham = np.logspace(-3, -1, 20) 

best_acc, best_alpha, best_k, best_leaf = cv_params_new(X_train, y_train, categorical, non_categorical,
                                                    sequence_ham = ham, choice = c, ks = [3])
# Out:
# Wed Oct  7 12:46:21 2020
# START...
# Computing Euclidean ...
# Adding Hamming 1 (Categorical)... alpha = 0.001
# Start CV...
# New best params found! alpha:0.001, k:3, leaf:10,
#                                                         acc:  0.68998124402044, st.error:  0.0015979496350606635,
#                                                         rmse: 0.8011173418651548, st.error:  0.0072205164247127135
# New best params found! alpha:0.001, k:3, leaf:20,
#                                                         acc:  0.69420633864642, st.error:  0.003615355802171918,
#                                                         rmse: 0.7970066060536131, st.error:  0.0036302345163051492
# Adding Hamming 1 (Categorical)... alpha = 0.0012742749857031334
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.001623776739188721
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.00206913808111479
# Start CV...
# New best params found! alpha:0.00206913808111479, k:3, leaf:20,
#                                                         acc:  0.6947069256497022, st.error:  0.0038669446158199794,
#                                                         rmse: 0.7965267330755694, st.error:  0.007158084809544505
# New best params found! alpha:0.00206913808111479, k:3, leaf:30,
#                                                         acc:  0.6947075901525622, st.error:  0.0035766959232012905,
#                                                         rmse: 0.7865149792208348, st.error:  0.007237207194208082
# New best params found! alpha:0.00206913808111479, k:3, leaf:50,
#                                                         acc:  0.6952629600078999, st.error:  0.004569685817464097,
#                                                         rmse: 0.7950849192051634, st.error:  0.009112308798164815
# Adding Hamming 1 (Categorical)... alpha = 0.0026366508987303583
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.003359818286283781
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.004281332398719396
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.00545559478116852
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.0069519279617756054
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.008858667904100823
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.011288378916846888
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.01438449888287663
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.018329807108324356
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.023357214690901212
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.029763514416313176
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.0379269019073225
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.04832930238571752
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.06158482110660261
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.07847599703514611
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.1
# Start CV...
# Wed Oct  7 14:06:37 2020

# %% [markdown]
# ### Finding the best alpha_3, fixing best_alpha_1
# START: alpha_1 = 0.00206913808111479, alpha_2 = 1, alpha_3 = 0
#
# END: alpha_1 = 0.00206913808111479, alpha_2 = 1, alpha_3 = 10

# %%
c = [0,1]
al_ham = 0.00206913808111479
pub = np.logspace(-3, 0, 20)

best_acc, best_alpha, best_k, best_leaf = cv_params_new(X_train, y_train, categorical, non_categorical,
                                                    sequence_pub = pub, a_ham = al_ham, choice = c, ks = [3])
# Out:
# Wed Oct  7 16:00:50 2020
# START...
# Computing Basic Matrix: Hamming 1 and Euclidean 2...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.001
# Start CV...
# New best params found! alpha:0.001, k:3, leaf:10,
#                                                         acc:  0.6903704418001351, st.error:  0.0016663242776706667,
#                                                         rmse: 0.8010746051527603, st.error:  0.007437915153043073
# New best params found! alpha:0.001, k:3, leaf:20,
#                                                         acc:  0.6945399345356508, st.error:  0.0038184457234268854,
#                                                         rmse: 0.7965828865900018, st.error:  0.0038968597484611922
# Adding Hamming 3 (Pubchem2d)... alpha = 0.0014384498882876629
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.00206913808111479
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.002976351441631319
# Start CV...
# New best params found! alpha:0.002976351441631319, k:3, leaf:20,
#                                                         acc:  0.6947069101961474, st.error:  0.00376394056841881,
#                                                         rmse: 0.7966329121585858, st.error:  0.007116306039935748
# New best params found! alpha:0.002976351441631319, k:3, leaf:30,
#                                                         acc:  0.695041186041793, st.error:  0.0036774318262528713,
#                                                         rmse: 0.7860920962970279, st.error:  0.007199481195984312
# New best params found! alpha:0.002976351441631319, k:3, leaf:50,
#                                                         acc:  0.6953185309912544, st.error:  0.004610221831113866,
#                                                         rmse: 0.7947587979000461, st.error:  0.009358488242609212
# Adding Hamming 3 (Pubchem2d)... alpha = 0.004281332398719396
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.006158482110660267
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.008858667904100823
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.012742749857031334
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.018329807108324356
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.026366508987303583
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.0379269019073225
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.05455594781168517
# Start CV...
# New best params found! alpha:0.05455594781168517, k:3, leaf:80,
#                                                         acc:  0.6957077442245043, st.error:  0.0024664984833094807,
#                                                         rmse: 0.7907098330975005, st.error:  0.006155978855669594
# Adding Hamming 3 (Pubchem2d)... alpha = 0.07847599703514611
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.11288378916846883
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.1623776739188721
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.23357214690901212
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.3359818286283781
# Start CV...
# New best params found! alpha:0.3359818286283781, k:3, leaf:30,
#                                                         acc:  0.6957633306614137, st.error:  0.0017123334303999192,
#                                                         rmse: 0.7919085769145962, st.error:  0.010963672595331474
# New best params found! alpha:0.3359818286283781, k:3, leaf:100,
#                                                         acc:  0.6974310010364699, st.error:  0.0035613232484663633,
#                                                         rmse: 0.7839894707423946, st.error:  0.010641263743825123
# Adding Hamming 3 (Pubchem2d)... alpha = 0.4832930238571752
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.6951927961775606
# Start CV...
# New best params found! alpha:0.6951927961775606, k:3, leaf:30,
#                                                         acc:  0.6977086859641388, st.error:  0.0036329671605332234,
#                                                         rmse: 0.7817665494103888, st.error:  0.010379856379054305
# Adding Hamming 3 (Pubchem2d)... alpha = 1.0
# Start CV...
# New best params found! alpha:1.0, k:3, leaf:100,
#                                                         acc:  0.6978204769801528, st.error:  0.00335683047426058,
#                                                         rmse: 0.7874894995084099, st.error:  0.00926578156015211
# Wed Oct  7 18:55:50 2020

# %%
c = [0,1]
al_ham = 0.00206913808111479
pub = [i for i in np.logspace(0,0.3,5)] + [5, 10, 100, 1000]

best_acc, best_alpha, best_k, best_leaf = cv_params_new(X_train, y_train, categorical, non_categorical,
                                                    sequence_pub = pub, a_ham = al_ham, choice = c, ks = [3])
# Out:
# Wed Oct  7 19:08:08 2020
# START...
# Computing Basic Matrix: Hamming 1 and Euclidean 2...
# Adding Hamming 3 (Pubchem2d)... alpha = 1.0
# Start CV...
# New best params found! alpha:1.0, k:3, leaf:10,
#                                                         acc:  0.6919271556511408, st.error:  0.0021087179731637826,
#                                                         rmse: 0.7955391543258468, st.error:  0.005211288449478407
# New best params found! alpha:1.0, k:3, leaf:20,
#                                                         acc:  0.6972640562830833, st.error:  0.004141454665682889,
#                                                         rmse: 0.789355812390519, st.error:  0.004159057944825247
# Adding Hamming 3 (Pubchem2d)... alpha = 1.1885022274370185
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 1.4125375446227544
# Start CV...
# New best params found! alpha:1.4125375446227544, k:3, leaf:90,
#                                                         acc:  0.6973203226764073, st.error:  0.0012941756998901752,
#                                                         rmse: 0.7782462662175457, st.error:  0.006937314434599878
# Adding Hamming 3 (Pubchem2d)... alpha = 1.6788040181225603
# Start CV...
# New best params found! alpha:1.6788040181225603, k:3, leaf:20,
#                                                         acc:  0.6975427920524839, st.error:  0.0031646913539690592,
#                                                         rmse: 0.787531679047741, st.error:  0.008285376619787364
# Adding Hamming 3 (Pubchem2d)... alpha = 1.9952623149688795
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 5
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 10
# Start CV...
# New best params found! alpha:10, k:3, leaf:50,
#                                                         acc:  0.6980989809462305, st.error:  0.0029562397743992073,
#                                                         rmse: 0.7836363197705459, st.error:  0.005320137382557348
# Adding Hamming 3 (Pubchem2d)... alpha = 100
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 1000
# Start CV...
# Wed Oct  7 20:26:52 2020

# %% [markdown]
# ### Finding again the best alpha_1, fixing best_alpha_3
#
# START: alpha_1 = 0.00206913808111479, alpha_2 = 1, alpha_3 = 10
#
# END: alpha_1 = 1, alpha_2 = 1, alpha_3 = 10

# %%
c = [1,0]
al_pub = 10

ham = [i for i in np.logspace(-2.7,-2,10)] + [0.05, 0.1, 0.5, 1, 1.5, 2]

best_acc, best_alpha, best_k, best_leaf = cv_params_new(X_train, y_train, categorical, non_categorical,
                                                    sequence_ham = ham, a_pub = al_pub, choice = c, ks = [3])
# Out:
# Wed Oct  7 20:33:39 2020
# START...
# Computing Euclidean and Pubchem2d Matrix...
# Adding Hamming 1 (Categorical)... alpha = 0.001995262314968879
# Start CV...
# New best params found! alpha:0.001995262314968879, k:3, leaf:10,
#                                                         acc:  0.5846215648486023, st.error:  0.002058225798475452,
#                                                         rmse: 0.9455513238579115, st.error:  0.004300381695815527
# New best params found! alpha:0.001995262314968879, k:3, leaf:20,
#                                                         acc:  0.5901798994684441, st.error:  0.0071514246815722075,
#                                                         rmse: 0.9338511759157491, st.error:  0.009760347369253266
# New best params found! alpha:0.001995262314968879, k:3, leaf:30,
#                                                         acc:  0.5927951045610704, st.error:  0.004157211535198321,
#                                                         rmse: 0.9433006342162983, st.error:  0.006170810389705857
# New best params found! alpha:0.001995262314968879, k:3, leaf:70,
#                                                         acc:  0.5944059367612718, st.error:  0.004731694769588577,
#                                                         rmse: 0.9293700095611028, st.error:  0.003698909475745528
# Adding Hamming 1 (Categorical)... alpha = 0.002386589786858581
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.00285466766349793
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.003414548873833601
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.004084238652674522
# Start CV...
# New best params found! alpha:0.004084238652674522, k:3, leaf:50,
#                                                         acc:  0.5947964326395769, st.error:  0.005668716966767922,
#                                                         rmse: 0.933767417807803, st.error:  0.012110521608114736
# Adding Hamming 1 (Categorical)... alpha = 0.004885273571519386
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.005843414133735175
# Start CV...
# New best params found! alpha:0.005843414133735175, k:3, leaf:60,
#                                                         acc:  0.5950739475781421, st.error:  0.0032900437955188802,
#                                                         rmse: 0.9347896868303393, st.error:  0.005574228327102063
# Adding Hamming 1 (Categorical)... alpha = 0.006989473207273479
# Start CV...
# New best params found! alpha:0.006989473207273479, k:3, leaf:20,
#                                                         acc:  0.5951844868562107, st.error:  0.004426418809314294,
#                                                         rmse: 0.9316475301070432, st.error:  0.012802148464819384
# Adding Hamming 1 (Categorical)... alpha = 0.00836030693651464
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.01
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.05
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.1
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.5
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 1
# Start CV...
# New best params found! alpha:1, k:3, leaf:50,
#                                                         acc:  0.5955737155430155, st.error:  0.0036121058641233605,
#                                                         rmse: 0.9334904249513778, st.error:  0.0036055130668041593
# New best params found! alpha:1, k:3, leaf:100,
#                                                         acc:  0.5956291783514859, st.error:  0.006221856904487677,
#                                                         rmse: 0.9324211684684208, st.error:  0.012290317727547993
# Adding Hamming 1 (Categorical)... alpha = 1.5
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 2
# Start CV...
# Wed Oct  7 23:03:53 2020

# %% [markdown]
# ### Finding again the best alpha_3, fixing best_alpha_1
#
# START: alpha_1 = 1, alpha_2 = 1, alpha_3 = 10
#
# END: alpha_1 = 1, alpha_2 = 1, alpha_3 = 100

# %%
c = [0,1]
al_ham = 1
pub = [i for i in np.logspace(1,1.4,8)] + [50, 100, 1000]

best_acc, best_alpha, best_k, best_leaf = cv_params_new(X_train, y_train, categorical, non_categorical,
                                                    sequence_pub = pub, a_ham = al_ham, choice = c, ks = [3])
# Out:
# Wed Oct  7 23:06:30 2020
# START...
# Computing Basic Matrix: Hamming 1 and Euclidean 2...
# Adding Hamming 3 (Pubchem2d)... alpha = 10.0
# Start CV...
# New best params found! alpha:10.0, k:3, leaf:10,
#                                                         acc:  0.6759152174709238, st.error:  0.0034387538070697046,
#                                                         rmse: 0.8446929153566343, st.error:  0.003471013289705158
# New best params found! alpha:10.0, k:3, leaf:20,
#                                                         acc:  0.6775267450810948, st.error:  0.0031063743209786094,
#                                                         rmse: 0.8435730280796532, st.error:  0.003505432628349781
# New best params found! alpha:10.0, k:3, leaf:40,
#                                                         acc:  0.6779716220190286, st.error:  0.0010743030894290457,
#                                                         rmse: 0.8393297366754549, st.error:  0.005698400827825148
# New best params found! alpha:10.0, k:3, leaf:60,
#                                                         acc:  0.6806404200399845, st.error:  0.0008920881878414524,
#                                                         rmse: 0.8303332133268301, st.error:  0.0026420555827838853
# Adding Hamming 3 (Pubchem2d)... alpha = 11.406249238513208
# Start CV...
# New best params found! alpha:11.406249238513208, k:3, leaf:30,
#                                                         acc:  0.6826415163151679, st.error:  0.004310745467000121,
#                                                         rmse: 0.8306760640584256, st.error:  0.007691023029127865
# New best params found! alpha:11.406249238513208, k:3, leaf:50,
#                                                         acc:  0.6833646345087463, st.error:  0.003133140067080397,
#                                                         rmse: 0.8294795905549279, st.error:  0.008321614259785032
# New best params found! alpha:11.406249238513208, k:3, leaf:70,
#                                                         acc:  0.6840316099374395, st.error:  0.0034035945682273487,
#                                                         rmse: 0.8291712376084399, st.error:  0.004060859754565766
# Adding Hamming 3 (Pubchem2d)... alpha = 13.010252169108314
# Start CV...
# New best params found! alpha:13.010252169108314, k:3, leaf:10,
#                                                         acc:  0.6840873200027879, st.error:  0.0017465130130419615,
#                                                         rmse: 0.8169085914782789, st.error:  0.007665252113006284
# New best params found! alpha:13.010252169108314, k:3, leaf:50,
#                                                         acc:  0.6846987244481265, st.error:  0.003008419706288196,
#                                                         rmse: 0.8213253416355425, st.error:  0.010634157078831216
# New best params found! alpha:13.010252169108314, k:3, leaf:60,
#                                                         acc:  0.6857554385309356, st.error:  0.0030964905848065343,
#                                                         rmse: 0.8230888827357798, st.error:  0.005194573960103504
# Adding Hamming 3 (Pubchem2d)... alpha = 14.839817889675647
# Start CV...
# New best params found! alpha:14.839817889675647, k:3, leaf:20,
#                                                         acc:  0.6867007324830479, st.error:  0.002650094322317309,
#                                                         rmse: 0.8185124511392108, st.error:  0.0038108070609115053
# New best params found! alpha:14.839817889675647, k:3, leaf:30,
#                                                         acc:  0.686701489707237, st.error:  0.003946076434027106,
#                                                         rmse: 0.8183406601901787, st.error:  0.005394058667413954
# Adding Hamming 3 (Pubchem2d)... alpha = 16.926666150378754
# Start CV...
# New best params found! alpha:16.926666150378754, k:3, leaf:10,
#                                                         acc:  0.6878134038880834, st.error:  0.0032195211618303954,
#                                                         rmse: 0.8181993178467488, st.error:  0.007671040254788236
# New best params found! alpha:16.926666150378754, k:3, leaf:20,
#                                                         acc:  0.6885354094257103, st.error:  0.003517591299875696,
#                                                         rmse: 0.8211609165279325, st.error:  0.007375396422151467
# Adding Hamming 3 (Pubchem2d)... alpha = 19.306977288832496
# Start CV...
# New best params found! alpha:19.306977288832496, k:3, leaf:90,
#                                                         acc:  0.6888129243642755, st.error:  0.0029173422078247126,
#                                                         rmse: 0.8123245351764055, st.error:  0.0059905962107314244
# Adding Hamming 3 (Pubchem2d)... alpha = 22.022019499873746
# Start CV...
# New best params found! alpha:22.022019499873746, k:3, leaf:70,
#                                                         acc:  0.6892581412804166, st.error:  0.004666718630085036,
#                                                         rmse: 0.8125429809830095, st.error:  0.005478749293982893
# Adding Hamming 3 (Pubchem2d)... alpha = 25.118864315095795
# Start CV...
# New best params found! alpha:25.118864315095795, k:3, leaf:30,
#                                                         acc:  0.6914826186914146, st.error:  0.002012707890822827,
#                                                         rmse: 0.8102407967142625, st.error:  0.008641223783553531
# Adding Hamming 3 (Pubchem2d)... alpha = 50
# Start CV...
# New best params found! alpha:50, k:3, leaf:10,
#                                                         acc:  0.6947069720103668, st.error:  0.0037193083448227265,
#                                                         rmse: 0.7946014559071, st.error:  0.007288401470000631
# New best params found! alpha:50, k:3, leaf:20,
#                                                         acc:  0.6952075899207588, st.error:  0.002401915441440094,
#                                                         rmse: 0.7988000367281438, st.error:  0.005832115937686127
# New best params found! alpha:50, k:3, leaf:30,
#                                                         acc:  0.6972642108186321, st.error:  0.0037539190329262274,
#                                                         rmse: 0.7851390970641138, st.error:  0.008022957243831019
# Adding Hamming 3 (Pubchem2d)... alpha = 100
# Start CV...
# New best params found! alpha:100, k:3, leaf:10,
#                                                         acc:  0.6982647048687816, st.error:  0.004224543728537154,
#                                                         rmse: 0.7808770421937719, st.error:  0.006128177677919658
# New best params found! alpha:100, k:3, leaf:70,
#                                                         acc:  0.6985430388457555, st.error:  0.0018034120052840804,
#                                                         rmse: 0.779500799442918, st.error:  0.007753777472147257
# Adding Hamming 3 (Pubchem2d)... alpha = 1000
# Start CV...
# Thu Oct  8 00:43:51 2020

# %% [markdown]
# ## Final model -- MULTICLASS -- K = 3

# %%
y = np.append(y_train,y_test)

del X_train, X_test, y_train, y_test

ham = 1
pub = 100
k = 3
leaf = 70

cv_multiclass_knn(X_try, y, ham, pub, k, leaf)
# Out:
# Basic Matrix... Thu Oct  8 10:20:02 2020
# Adding pubchem2d Thu Oct  8 10:23:27 2020
# End distance matrix... Thu Oct  8 10:36:15 2020
# Accuracy: 	 0.7348951998038259, se: 0.0015951052564620268
# RMSE: 		 0.7194612001611612, se: 0.006722519007522795
# W. Recall: 0.7348951998038259, se:0.0015951052564620268
# W. Precision: 0.7361102745239585, se: 0.0017262402569629813

# %% [markdown]
# ## MULTICLASS -- K = 5
# ### Finding the best alpha_1 for the problem
#
# START: alpha_1 = 0, alpha_2 = 1, alpha_3 = 0
#
# END: alpha_1 = 0.11288378916846889, alpha_2 = 1, alpha_3 = 0

# %%
c = [0,0]
ham = [i for i in np.logspace(-3, -2, 5)] + [i for i in np.logspace(-2, 0.5, 20) ]

best_acc, best_alpha, best_k, best_leaf = cv_params_new(X_train, y_train, categorical, non_categorical,
                                                    sequence_ham = ham, choice = c, ks = [5])
# Out:
# Thu Oct  8 00:48:41 2020
# START...
# Computing Euclidean ...
# Adding Hamming 1 (Categorical)... alpha = 0.001
# Start CV...
# New best params found! alpha:0.001, k:5, leaf:10,
#                                                         acc:  0.6646273692038158, st.error:  0.0032536255150229683,
#                                                         rmse: 0.8212029138071324, st.error:  0.007196875193561847
# New best params found! alpha:0.001, k:5, leaf:20,
#                                                         acc:  0.6665737135340534, st.error:  0.004978374400579129,
#                                                         rmse: 0.8108664017188154, st.error:  0.006596650614280178
# New best params found! alpha:0.001, k:5, leaf:70,
#                                                         acc:  0.6672414925476005, st.error:  0.00307232633614994,
#                                                         rmse: 0.8207551397825654, st.error:  0.005170232705348263
# Adding Hamming 1 (Categorical)... alpha = 0.0017782794100389228
# Start CV...
# New best params found! alpha:0.0017782794100389228, k:5, leaf:30,
#                                                         acc:  0.6679079580089825, st.error:  0.004068141081760857,
#                                                         rmse: 0.8222389139193197, st.error:  0.0038994992200328334
# Adding Hamming 1 (Categorical)... alpha = 0.0031622776601683794
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.005623413251903491
# Start CV...
# New best params found! alpha:0.005623413251903491, k:5, leaf:40,
#                                                         acc:  0.6679083752549644, st.error:  0.003528104552551376,
#                                                         rmse: 0.8159956051084265, st.error:  0.008354489832479215
# New best params found! alpha:0.005623413251903491, k:5, leaf:100,
#                                                         acc:  0.668687728934757, st.error:  0.004442417242503702,
#                                                         rmse: 0.8101508076214952, st.error:  0.01049954404062336
# Adding Hamming 1 (Categorical)... alpha = 0.01
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.01
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.01353876180022544
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.018329807108324356
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.024816289228368264
# Start CV...
# New best params found! alpha:0.024816289228368264, k:5, leaf:70,
#                                                         acc:  0.670243639200909, st.error:  0.0012674780282602984,
#                                                         rmse: 0.812178672367458, st.error:  0.004992419931297778
# Adding Hamming 1 (Categorical)... alpha = 0.03359818286283781
# Start CV...
# New best params found! alpha:0.03359818286283781, k:5, leaf:10,
#                                                         acc:  0.6702981593425316, st.error:  0.004823610270611872,
#                                                         rmse: 0.8131117156421069, st.error:  0.004663294962370136
# Adding Hamming 1 (Categorical)... alpha = 0.04548777947003778
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.06158482110660264
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.08337822234717891
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.11288378916846889
# Start CV...
# New best params found! alpha:0.11288378916846889, k:5, leaf:100,
#                                                         acc:  0.6725780995619999, st.error:  0.006288245811475771,
#                                                         rmse: 0.8206471675573251, st.error:  0.014011690381253635
# Adding Hamming 1 (Categorical)... alpha = 0.15283067326587688
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.20691380811147891
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.2801356761198867
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.37926901907322497
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.5134832907437552
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.6951927961775606
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.9412049672680666
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 1.2742749857031335
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 1.725210549942041
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 2.3357214690901213
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 3.1622776601683795
# Start CV...
# Thu Oct  8 02:46:03 2020

# %% [markdown]
# ### Finding the best alpha_3, fixing best_alpha_1
# START: alpha_1 = 0.11288378916846889 , alpha_2 = 1, alpha_3 = 0
#
# END: alpha_1 = 0.11288378916846889 , alpha_2 = 1, alpha_3 =  0.08858667904100823

# %%
c = [0,1]
al_ham = 0.11288378916846889
pub = [i for i in np.logspace(-2, 0, 20) ] + [1.5, 2, 10, 100, 1000]

best_acc, best_alpha, best_k, best_leaf = cv_params_new(X_train, y_train, categorical, non_categorical,
                                                    sequence_pub = pub, a_ham = al_ham, choice = c, ks = [5])
# Out:
# Thu Oct  8 06:33:18 2020
# START...
# Computing Basic Matrix: Hamming 1 and Euclidean 2...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.01
# Start CV...
# New best params found! alpha:0.01, k:5, leaf:10,
#                                                         acc:  0.6668521556859115, st.error:  0.0009265824063318593,
#                                                         rmse: 0.8306759684394383, st.error:  0.004157103390011953
# New best params found! alpha:0.01, k:5, leaf:20,
#                                                         acc:  0.6689644557420233, st.error:  0.004827741434402463,
#                                                         rmse: 0.8190929084809557, st.error:  0.005216369343412883
# New best params found! alpha:0.01, k:5, leaf:100,
#                                                         acc:  0.67091025919784, st.error:  0.0030450429447324364,
#                                                         rmse: 0.8201660875450827, st.error:  0.0020699903863519277
# Adding Hamming 3 (Pubchem2d)... alpha = 0.012742749857031334
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.016237767391887217
# Start CV...
# New best params found! alpha:0.016237767391887217, k:5, leaf:40,
#                                                         acc:  0.6715222972389288, st.error:  0.002563891982966468,
#                                                         rmse: 0.8201281970071186, st.error:  0.011478365145908045
# New best params found! alpha:0.016237767391887217, k:5, leaf:60,
#                                                         acc:  0.6723011100443006, st.error:  0.004418500814770894,
#                                                         rmse: 0.8225259312739839, st.error:  0.012683496654514818
# Adding Hamming 3 (Pubchem2d)... alpha = 0.0206913808111479
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.026366508987303583
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.03359818286283781
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.04281332398719394
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.0545559478116852
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.06951927961775606
# Start CV...
# New best params found! alpha:0.06951927961775606, k:5, leaf:70,
#                                                         acc:  0.6748581634099071, st.error:  0.002116907636918869,
#                                                         rmse: 0.8162058194381918, st.error:  0.005074241796010931
# Adding Hamming 3 (Pubchem2d)... alpha = 0.08858667904100823
# Start CV...
# New best params found! alpha:0.08858667904100823, k:5, leaf:10,
#                                                         acc:  0.6762474379937701, st.error:  0.004594069698548528,
#                                                         rmse: 0.8108239294092513, st.error:  0.006863870929643966
# Adding Hamming 3 (Pubchem2d)... alpha = 0.11288378916846889
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.14384498882876628
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.18329807108324356
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.23357214690901212
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.29763514416313175
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.37926901907322497
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.4832930238571752
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.615848211066026
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.7847599703514611
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 1.0
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 1.5
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 2
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 10
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 100
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 1000
# Start CV...
# Thu Oct  8 10:18:28 2020

# %% [markdown]
# ### Finding again the best alpha_1, fixing best_alpha_3
#
# START: alpha_1 = 0.11288378916846889 , alpha_2 = 1, alpha_3 = 0.08858667904100823
#
# END: alpha_1 = 0.774263682681127 , alpha_2 = 1, alpha_3 = 0.08858667904100823

# %%
c = [1,0]
al_pub = 10

ham = [i for i in np.logspace(-1, 0, 10)] + [1.1, 1.5, 2, 10, 100]

best_acc, best_alpha, best_k, best_leaf = cv_params_new(X_train, y_train, categorical, non_categorical,
                                                    sequence_ham = ham, a_pub = al_pub, choice = c, ks = [5])
# Out:
# Thu Oct  8 11:08:26 2020
# START...
# Computing Euclidean and Pubchem2d Matrix...
# Adding Hamming 1 (Categorical)... alpha = 0.1
# Start CV...
# New best params found! alpha:0.1, k:5, leaf:10,
#                                                         acc:  0.5859558093235315, st.error:  0.004031385251592011,
#                                                         rmse: 0.9214804228981427, st.error:  0.007096176122142234
# New best params found! alpha:0.1, k:5, leaf:60,
#                                                         acc:  0.5892357799865029, st.error:  0.005711865142076941,
#                                                         rmse: 0.9099137207211532, st.error:  0.008805354782220519
# Adding Hamming 1 (Categorical)... alpha = 0.1291549665014884
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.16681005372000587
# Start CV...
# New best params found! alpha:0.16681005372000587, k:5, leaf:80,
#                                                         acc:  0.5914595156268665, st.error:  0.005976675546911038,
#                                                         rmse: 0.922637324274177, st.error:  0.018387477010762175
# Adding Hamming 1 (Categorical)... alpha = 0.21544346900318834
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.2782559402207124
# Start CV...
# New best params found! alpha:0.2782559402207124, k:5, leaf:70,
#                                                         acc:  0.5921823092957924, st.error:  0.005082197014202371,
#                                                         rmse: 0.9030988311522318, st.error:  0.011704763736657147
# Adding Hamming 1 (Categorical)... alpha = 0.35938136638046275
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.46415888336127786
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.5994842503189409
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.774263682681127
# Start CV...
# New best params found! alpha:0.774263682681127, k:5, leaf:50,
#                                                         acc:  0.592960890297841, st.error:  0.004071842518622743,
#                                                         rmse: 0.9139305541360467, st.error:  0.01172648356124909
# Adding Hamming 1 (Categorical)... alpha = 1.0
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 1.1
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 1.5
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 2
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 10
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 100
# Start CV...
# Thu Oct  8 13:32:56 2020

# %% [markdown]
# ### Finding again the best alpha_3, fixing best_alpha_1
#
# START: alpha_1 = 0.774263682681127 , alpha_2 = 1, alpha_3 = 0.08858667904100823
#
# END: alpha_1 = 0.774263682681127 , alpha_2 = 1, alpha_3 = ---------------

# %%
c = [0,1]
al_ham = 0.774263682681127
pub = [i for i in np.logspace(-1.1,0,15)] + [1.5, 2, 10, 100, 1000, 10000]

best_acc, best_alpha, best_k, best_leaf = cv_params_new(X_train, y_train, categorical, non_categorical,
                                                    sequence_pub = pub, a_ham = al_ham, choice = c, ks = [5])
# Out:
# Thu Oct  8 13:43:28 2020
# START...
# Computing Basic Matrix: Hamming 1 and Euclidean 2...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.07943282347242814
# Start CV...
# New best params found! alpha:0.07943282347242814, k:5, leaf:10,
#                                                         acc:  0.607528508331707, st.error:  0.0021537710058528287,
#                                                         rmse: 0.9752715640899847, st.error:  0.0069680814251431
# New best params found! alpha:0.07943282347242814, k:5, leaf:60,
#                                                         acc:  0.60797214898525, st.error:  0.0034689652323369,
#                                                         rmse: 0.9673461168830514, st.error:  0.007902821981398815
# New best params found! alpha:0.07943282347242814, k:5, leaf:90,
#                                                         acc:  0.6079722262530244, st.error:  0.0044230020059025646,
#                                                         rmse: 0.9643704054871804, st.error:  0.005083502937111714
# Adding Hamming 3 (Pubchem2d)... alpha = 0.09518563874058612
# Start CV...
# New best params found! alpha:0.09518563874058612, k:5, leaf:60,
#                                                         acc:  0.6094189571539375, st.error:  0.0031544774344312463,
#                                                         rmse: 0.9661794205033708, st.error:  0.007440082624572972
# Adding Hamming 3 (Pubchem2d)... alpha = 0.11406249238513205
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.1366829318082926
# Start CV...
# New best params found! alpha:0.1366829318082926, k:5, leaf:30,
#                                                         acc:  0.6116424918980875, st.error:  0.0022229100889345635,
#                                                         rmse: 0.9594180530286291, st.error:  0.0066899279097897965
# Adding Hamming 3 (Pubchem2d)... alpha = 0.1637893706954064
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.19627145538862117
# Start CV...
# New best params found! alpha:0.19627145538862117, k:5, leaf:40,
#                                                         acc:  0.6124765820692712, st.error:  0.004160476851164253,
#                                                         rmse: 0.9569157705447451, st.error:  0.004491407334237477
# Adding Hamming 3 (Pubchem2d)... alpha = 0.23519526350709588
# Start CV...
# New best params found! alpha:0.23519526350709588, k:5, leaf:10,
#                                                         acc:  0.6141997152527977, st.error:  0.0030016373773004883,
#                                                         rmse: 0.9478949889383157, st.error:  0.009498778766233824
# Adding Hamming 3 (Pubchem2d)... alpha = 0.28183829312644537
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.337731390879101
# Start CV...
# New best params found! alpha:0.337731390879101, k:5, leaf:70,
#                                                         acc:  0.6145894539069137, st.error:  0.004038520133215587,
#                                                         rmse: 0.9486844311195888, st.error:  0.004629229535228335
# New best params found! alpha:0.337731390879101, k:5, leaf:80,
#                                                         acc:  0.617312926605041, st.error:  0.004988361127733059,
#                                                         rmse: 0.9426313784508016, st.error:  0.006944393717834339
# Adding Hamming 3 (Pubchem2d)... alpha = 0.40470899507597613
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.4849693428528198
# Start CV...
# New best params found! alpha:0.4849693428528198, k:5, leaf:20,
#                                                         acc:  0.619592372310753, st.error:  0.003951181789837426,
#                                                         rmse: 0.9372887757585808, st.error:  0.009260521976636226
# Adding Hamming 3 (Pubchem2d)... alpha = 0.5811466173687162
# Start CV...
# New best params found! alpha:0.5811466173687162, k:5, leaf:30,
#                                                         acc:  0.6196482987258699, st.error:  0.0025373965936784965,
#                                                         rmse: 0.9405652591047812, st.error:  0.004475805235156985
# New best params found! alpha:0.5811466173687162, k:5, leaf:60,
#                                                         acc:  0.6216505694712242, st.error:  0.0035177113429853643,
#                                                         rmse: 0.9303984834268917, st.error:  0.00469641181067244
# Adding Hamming 3 (Pubchem2d)... alpha = 0.6963974029624321
# Start CV...
# New best params found! alpha:0.6963974029624321, k:5, leaf:80,
#                                                         acc:  0.6236512948610903, st.error:  0.0023991099268789017,
#                                                         rmse: 0.9200395354537962, st.error:  0.010141013977258
# Adding Hamming 3 (Pubchem2d)... alpha = 0.8345042857663657
# Start CV...
# New best params found! alpha:0.8345042857663657, k:5, leaf:30,
#                                                         acc:  0.6252080087120961, st.error:  0.004068707930008839,
#                                                         rmse: 0.9246193375989847, st.error:  0.00442910274670948
# New best params found! alpha:0.8345042857663657, k:5, leaf:50,
#                                                         acc:  0.6260427015719201, st.error:  0.004277971052311541,
#                                                         rmse: 0.9200917822702941, st.error:  0.019227552297903325
# Adding Hamming 3 (Pubchem2d)... alpha = 1.0
# Start CV...
# New best params found! alpha:1.0, k:5, leaf:10,
#                                                         acc:  0.6263755247834069, st.error:  0.0038998557222323623,
#                                                         rmse: 0.9179426772579433, st.error:  0.004760465864629034
# New best params found! alpha:1.0, k:5, leaf:30,
#                                                         acc:  0.6307681823049689, st.error:  0.0022890086304064817,
#                                                         rmse: 0.9168083311067494, st.error:  0.006589176195767806
# Adding Hamming 3 (Pubchem2d)... alpha = 1.5
# Start CV...
# New best params found! alpha:1.5, k:5, leaf:10,
#                                                         acc:  0.63460520726076, st.error:  0.003680941546804644,
#                                                         rmse: 0.9031645654908808, st.error:  0.008088480969604307
# New best params found! alpha:1.5, k:5, leaf:20,
#                                                         acc:  0.6366059635577359, st.error:  0.0022361563268587944,
#                                                         rmse: 0.896970202604973, st.error:  0.008518929763489719
# New best params found! alpha:1.5, k:5, leaf:60,
#                                                         acc:  0.6369396058076313, st.error:  0.0027372761188500776,
#                                                         rmse: 0.8982276566464332, st.error:  0.0030057744293888666
# Adding Hamming 3 (Pubchem2d)... alpha = 2
# Start CV...
# New best params found! alpha:2, k:5, leaf:10,
#                                                         acc:  0.6387750708815929, st.error:  0.003231784697060424,
#                                                         rmse: 0.8847125874629895, st.error:  0.008390784381774347
# New best params found! alpha:2, k:5, leaf:20,
#                                                         acc:  0.6394416290643042, st.error:  0.0034574230237698913,
#                                                         rmse: 0.8767270406179799, st.error:  0.006499937504674949
# New best params found! alpha:2, k:5, leaf:30,
#                                                         acc:  0.6421108752383518, st.error:  0.002649744484960952,
#                                                         rmse: 0.8845936278555657, st.error:  0.007287293508292289
# New best params found! alpha:2, k:5, leaf:50,
#                                                         acc:  0.64222277442925, st.error:  0.00513787347012452,
#                                                         rmse: 0.8772496253156497, st.error:  0.01207630171359636
# New best params found! alpha:2, k:5, leaf:100,
#                                                         acc:  0.6426661369188054, st.error:  0.002375640240307185,
#                                                         rmse: 0.8783268179891583, st.error:  0.008821299514991469
# Adding Hamming 3 (Pubchem2d)... alpha = 10
# Start CV...
# New best params found! alpha:10, k:5, leaf:10,
#                                                         acc:  0.6661846857434621, st.error:  0.003064454001194414,
#                                                         rmse: 0.8114504943147214, st.error:  0.009921746042263103
# New best params found! alpha:10, k:5, leaf:20,
#                                                         acc:  0.6674079582407859, st.error:  0.0016260798875357854,
#                                                         rmse: 0.8168949415290927, st.error:  0.004720413215430576
# New best params found! alpha:10, k:5, leaf:60,
#                                                         acc:  0.670299411080477, st.error:  0.0017198016342288072,
#                                                         rmse: 0.812455810051992, st.error:  0.004854500801423748
# New best params found! alpha:10, k:5, leaf:80,
#                                                         acc:  0.6716893501671997, st.error:  0.0016526580001931402,
#                                                         rmse: 0.8124369826882065, st.error:  0.004177204322336371
# Adding Hamming 3 (Pubchem2d)... alpha = 100
# Start CV...
# New best params found! alpha:100, k:5, leaf:10,
#                                                         acc:  0.6749141670927985, st.error:  0.003923930466731978,
#                                                         rmse: 0.7946489112167785, st.error:  0.005781682156037206
# New best params found! alpha:100, k:5, leaf:40,
#                                                         acc:  0.6751361574086738, st.error:  0.0025202558676429773,
#                                                         rmse: 0.7929088501375358, st.error:  0.0075607364629769625
# New best params found! alpha:100, k:5, leaf:60,
#                                                         acc:  0.6754693360519227, st.error:  0.004290944738434804,
#                                                         rmse: 0.7934825280913633, st.error:  0.0097179264976297
# New best params found! alpha:100, k:5, leaf:90,
#                                                         acc:  0.6780276566090295, st.error:  0.002749287575244687,
#                                                         rmse: 0.7896112008547427, st.error:  0.009853474957974352
# Adding Hamming 3 (Pubchem2d)... alpha = 1000
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 10000
# Start CV...
# Thu Oct  8 16:52:54 2020

# %% [markdown]
# ## Final model -- MULTICLASS -- K = 5

# %%
y = np.append(y_train,y_test)

del X_train, X_test, y_train, y_test

ham = 0.774263682681127
pub = 100
k = 5
leaf = 90

cv_multiclass_knn(X_try, y, ham, pub, k, leaf)
# Out:
# Basic Matrix... Thu Oct  8 16:56:01 2020
# Adding pubchem2d Thu Oct  8 16:59:29 2020
# End distance matrix... Thu Oct  8 17:12:49 2020
# Accuracy: 	 0.7131417999669112, se: 0.0027060852688013727
# RMSE: 		 0.7372753493731985, se: 0.006932540723191115
# W. Recall: 	 0.7131417999669112, se:0.0027060852688013727
# W. Precision: 	 0.7145671758599701, se: 0.0028212544594714978
