# %% [markdown]
# # First Models
#
# - **Categorical features**: conc1_type, exposure_type, control_type, media_type, application_freq_unit, class, tax_order, family, genus, species
#
# - **Non Categorical features**: obs_duration_mean, conc1_mean, atom_number, alone_atom_number, bonds_number, doubleBond, tripleBond, ring_number, Mol, MorganDensity, LogP, oh_count
#
# It turns out that *obs_duration_mean* have to be considered as a categorical feature in order to maxime the metrics.
#
# ## BINARY

# %%
from helper_knn import *

X_try, X_train, X_test, y_train, y_test, len_X_train = load_data_knn('data/lc_db_processed.csv',
                                                                     encoding = 'binary', seed = 42)

# Best combination
# categorical = ['class', 'tax_order', 'family', 'genus', "species", 'control_type', 'media_type',
#                'application_freq_unit',"exposure_type", "conc1_type", 'obs_duration_mean']

# non_categorical = ['ring_number', 'tripleBond', 'doubleBond', 'alone_atom_number', 'oh_count',
#                    'atom_number', 'bonds_number', 'Mol', 'MorganDensity', 'LogP']

categorical = ['class', 'tax_order', 'family', 'genus', 'species', 'control_type', 'media_type',
               'application_freq_unit', 'exposure_type', 'conc1_type']

non_categorical = ['ring_number', 'tripleBond',  'doubleBond', 'alone_atom_number', 'oh_count',
                   'atom_number', 'bonds_number', 'Mol', 'MorganDensity', 'LogP', 'obs_duration_mean']

# %% [markdown]
# ### Finding the best alpha_1 for the problem
#
# START: alpha_1 = 0, alpha_2 = 1, alpha_3 = 0
#
# END: alpha_1 = 0.007880462815669913, alpha_2 = 1, alpha_3 = 0

# %%
c = [0,0]
ham = np.logspace(-3, -1, 30) 

best_acc, best_alpha, best_k, best_leaf = cv_params_new(X_train, y_train, categorical, non_categorical,
                                                    sequence_ham = ham, choice = c, ks = [1])
# Out:
# Wed Sep  9 17:10:11 2020
# START...
# Computing Euclidean ...
# Adding Hamming 1 (Categorical)... alpha = 0.001
# Start CV...
# New best params found! alpha:0.001, k:1, leaf:10,
#                                                         acc:  0.849216296144508, st.error:  0.004163826444549491,
#                                                         rmse: 0.38815851135308044, st.error:  0.005400785120065688
# New best params found! alpha:0.001, k:1, leaf:40,
#                                                         acc:  0.8493273762969975, st.error:  0.0028768087742139,
#                                                         rmse: 0.38809394752254917, st.error:  0.003732010161002568
# New best params found! alpha:0.001, k:1, leaf:50,
#                                                         acc:  0.8512734270096924, st.error:  0.0025523525709176295,
#                                                         rmse: 0.38559334997435263, st.error:  0.0033294686461991735
# Adding Hamming 1 (Categorical)... alpha = 0.0011721022975334804
# Start CV...
# New best params found! alpha:0.0011721022975334804, k:1, leaf:100,
#                                                         acc:  0.8513285652935101, st.error:  0.0038898355175030178,
#                                                         rmse: 0.38544801262880524, st.error:  0.005031507403210155
# Adding Hamming 1 (Categorical)... alpha = 0.0013738237958832624
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.0016102620275609393
# Start CV...
# New best params found! alpha:0.0016102620275609393, k:1, leaf:30,
#                                                         acc:  0.8527744771560144, st.error:  0.0012297180463088136,
#                                                         rmse: 0.3836862752313436, st.error:  0.0016097393487285864
# Adding Hamming 1 (Categorical)... alpha = 0.0018873918221350976
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.00221221629107045
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.002592943797404667
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.0030391953823131978
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.003562247890262444
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.0041753189365604
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.004893900918477494
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.005736152510448681
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.006723357536499335
# Start CV...
# New best params found! alpha:0.006723357536499335, k:1, leaf:20,
#                                                         acc:  0.8528303572104665, st.error:  0.00203881926064653,
#                                                         rmse: 0.383590279388282, st.error:  0.002652373859080266
# Adding Hamming 1 (Categorical)... alpha = 0.007880462815669913
# Start CV...
# New best params found! alpha:0.007880462815669913, k:1, leaf:10,
#                                                         acc:  0.8529971937889691, st.error:  0.0022365619885167175,
#                                                         rmse: 0.38336541044736816, st.error:  0.0029055242019254105
# Adding Hamming 1 (Categorical)... alpha = 0.009236708571873866
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.010826367338740546
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.01268961003167922
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.01487352107293511
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.017433288221999882
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.020433597178569417
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.02395026619987486
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.02807216203941177
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.03290344562312668
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.03856620421163472
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.04520353656360243
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.05298316906283707
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.06210169418915616
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.0727895384398315
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.08531678524172806
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.1
# Start CV...
# Wed Sep  9 19:41:32 2020

# %% [markdown]
# ### Finding the best alpha_3, fixing best_alpha_1
# START: alpha_1 = 0.007880462815669913, alpha_2 = 1, alpha_3 = 0
#
# END: alpha_1 = 0.007880462815669913, alpha_2 = 1, alpha_3 = 0.007880462815669913

# %%
c = [0,1]
al_ham = 0.007880462815669913
pub = np.logspace(-3, -1, 30)

best_acc, best_alpha, best_k, best_leaf = cv_params_new(X_train, y_train, categorical, non_categorical,
                                                    sequence_pub = pub, a_ham = al_ham, choice = c, ks = [1])
# Out:
# Wed Sep  9 22:27:51 2020
# START...
# Computing Basic Matrix: Hamming 1 and Euclidean 2...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.001
# Start CV...
# New best params found! alpha:0.001, k:1, leaf:10,
#                                                         acc:  0.8499946917038981, st.error:  0.004072696390337732,
#                                                         rmse: 0.3871599836040902, st.error:  0.00530224932888054
# New best params found! alpha:0.001, k:1, leaf:50,
#                                                         acc:  0.8514958500251044, st.error:  0.002467863015571247,
#                                                         rmse: 0.385308158201802, st.error:  0.0032316094299440785
# Adding Hamming 3 (Pubchem2d)... alpha = 0.0011721022975334804
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.0013738237958832624
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.0016102620275609393
# Start CV...
# New best params found! alpha:0.0016102620275609393, k:1, leaf:30,
#                                                         acc:  0.8522740755953908, st.error:  0.0012425906466247316,
#                                                         rmse: 0.3843375551548098, st.error:  0.0016254308838621098
# Adding Hamming 3 (Pubchem2d)... alpha = 0.0018873918221350976
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.00221221629107045
# Start CV...
# New best params found! alpha:0.00221221629107045, k:1, leaf:80,
#                                                         acc:  0.8525525486543586, st.error:  0.002876883708854206,
#                                                         rmse: 0.383916838506153, st.error:  0.0037186172524844205
# Adding Hamming 3 (Pubchem2d)... alpha = 0.002592943797404667
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.0030391953823131978
# Start CV...
# New best params found! alpha:0.0030391953823131978, k:1, leaf:100,
#                                                         acc:  0.853108227580794, st.error:  0.0016705909882862545,
#                                                         rmse: 0.3832399469719934, st.error:  0.0021745956009005564
# Adding Hamming 3 (Pubchem2d)... alpha = 0.003562247890262444
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.0041753189365604
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.004893900918477494
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.005736152510448681
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.006723357536499335
# Start CV...
# New best params found! alpha:0.006723357536499335, k:1, leaf:20,
#                                                         acc:  0.8531083666627879, st.error:  0.00203852739021925,
#                                                         rmse: 0.3832277754575184, st.error:  0.002650728913620505
# Adding Hamming 3 (Pubchem2d)... alpha = 0.007880462815669913
# Start CV...
# New best params found! alpha:0.007880462815669913, k:1, leaf:10,
#                                                         acc:  0.8535531663329472, st.error:  0.0021967718682802877,
#                                                         rmse: 0.3826409533113155, st.error:  0.0028607042865589913
# Adding Hamming 3 (Pubchem2d)... alpha = 0.009236708571873866
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.010826367338740546
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.01268961003167922
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.01487352107293511
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.017433288221999882
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.020433597178569417
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.02395026619987486
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.02807216203941177
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.03290344562312668
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.03856620421163472
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.04520353656360243
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.05298316906283707
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.06210169418915616
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.0727895384398315
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.08531678524172806
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.1
# Start CV...
# Thu Sep 10 03:30:44 2020

# %% [markdown]
# ### Finding again the best alpha_1, fixing best_alpha_3
#
# START: alpha_1 = 0.007880462815669913, alpha_2 = 1, alpha_3 = 0.007880462815669913
#
# END: alpha_1 = 0.008620689655172414, alpha_2 = 1, alpha_3 = 0.007880462815669913

# %%
c = [1,0]
al_pub = 0.007880462815669913

ham = np.linspace(0.005,0.01,30)

best_acc, best_alpha, best_k, best_leaf = cv_params_new(X_train, y_train, categorical, non_categorical,
                                                    sequence_ham = ham, a_pub = al_pub, choice = c, ks = [1])
# Out:
# Thu Sep 10 11:11:07 2020
# START...
# Computing Euclidean and Pubchem2d Matrix...
# Adding Hamming 1 (Categorical)... alpha = 0.005
# Start CV...
# New best params found! alpha:0.005, k:1, leaf:10,
#                                                         acc:  0.8119654557415596, st.error:  0.0036428205032030276,
#                                                         rmse: 0.4335484929433071, st.error:  0.004190719658587571
# New best params found! alpha:0.005, k:1, leaf:30,
#                                                         acc:  0.8126320757384906, st.error:  0.0029976566349513394,
#                                                         rmse: 0.43280549797132634, st.error:  0.0034396652199607976
# New best params found! alpha:0.005, k:1, leaf:50,
#                                                         acc:  0.8143563524850785, st.error:  0.004578153158321574,
#                                                         rmse: 0.4307330207814454, st.error:  0.00530830301067345
# Adding Hamming 1 (Categorical)... alpha = 0.005172413793103448
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.005344827586206896
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.005517241379310345
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.005689655172413793
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.0058620689655172415
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.00603448275862069
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.0062068965517241385
# Start CV...
# New best params found! alpha:0.0062068965517241385, k:1, leaf:20,
#                                                         acc:  0.8145218600578612, st.error:  0.0034473119761058556,
#                                                         rmse: 0.4305970009829375, st.error:  0.00401131794548022
# New best params found! alpha:0.0062068965517241385, k:1, leaf:80,
#                                                         acc:  0.8145775083089901, st.error:  0.004218659507785638,
#                                                         rmse: 0.43049709362200766, st.error:  0.0048668283823827254
# Adding Hamming 1 (Categorical)... alpha = 0.006379310344827587
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.006551724137931035
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.006724137931034483
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.006896551724137931
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.00706896551724138
# Start CV...
# New best params found! alpha:0.00706896551724138, k:1, leaf:20,
#                                                         acc:  0.8146886811828089, st.error:  0.0032593850773600607,
#                                                         rmse: 0.4304108876953462, st.error:  0.0038008739289519186
# Adding Hamming 1 (Categorical)... alpha = 0.007241379310344828
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.007413793103448276
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.007586206896551725
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.007758620689655172
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.007931034482758621
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.008103448275862069
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.008275862068965517
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.008448275862068966
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.008620689655172414
# Start CV...
# New best params found! alpha:0.008620689655172414, k:1, leaf:50,
#                                                         acc:  0.8160784657339828, st.error:  0.0033826093696143825,
#                                                         rmse: 0.4287867436528726, st.error:  0.003983175039553435
# Adding Hamming 1 (Categorical)... alpha = 0.008793103448275863
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.008965517241379312
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.009137931034482759
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.009310344827586206
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.009482758620689657
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.009655172413793104
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.009827586206896551
# Start CV...
# Adding Hamming 1 (Categorical)... alpha = 0.01
# Start CV...
# Thu Sep 10 16:30:47 2020

# %% [markdown]
# ### Finding again the best alpha_3, fixing best_alpha_1
#
# START: alpha_1 = 0.008620689655172414, alpha_2 = 1, alpha_3 = 0.007880462815669913
#
# END: alpha_1 = 0.008620689655172414, alpha_2 = 1, alpha_3 = 0.008736842105263157

# %%
c = [0,1]
al_ham = 0.008620689655172414
pub = np.linspace(0.006, 0.01, 20)

best_acc, best_alpha, best_k, best_leaf = cv_params_new(X_train, y_train, categorical, non_categorical,
                                                    sequence_pub = pub, a_ham = al_ham, choice = c, ks = [1])
# Out:
# Thu Sep 10 16:38:21 2020
# START...
# Computing Basic Matrix: Hamming 1 and Euclidean 2...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.006
# Start CV...
# New best params found! alpha:0.006, k:1, leaf:10,
#                                                         acc:  0.850161481921736, st.error:  0.004119366050285759,
#                                                         rmse: 0.3869410208922664, st.error:  0.005365734551638392
# New best params found! alpha:0.006, k:1, leaf:50,
#                                                         acc:  0.8515514519155687, st.error:  0.002471883245055704,
#                                                         rmse: 0.3852358349083632, st.error:  0.003236494511341651
# Adding Hamming 3 (Pubchem2d)... alpha = 0.006210526315789474
# Start CV...
# New best params found! alpha:0.006210526315789474, k:1, leaf:20,
#                                                         acc:  0.8516064974780571, st.error:  0.0021877007622684587,
#                                                         rmse: 0.3851770432737597, st.error:  0.0028349540043494307
# Adding Hamming 3 (Pubchem2d)... alpha = 0.006421052631578947
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.0066315789473684215
# Start CV...
# New best params found! alpha:0.0066315789473684215, k:1, leaf:30,
#                                                         acc:  0.8525520695941573, st.error:  0.0012487998796467488,
#                                                         rmse: 0.3839755693651785, st.error:  0.0016349722115207382
# Adding Hamming 3 (Pubchem2d)... alpha = 0.006842105263157895
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.0070526315789473685
# Start CV...
# New best params found! alpha:0.0070526315789473685, k:1, leaf:80,
#                                                         acc:  0.8528305271995702, st.error:  0.0028582556400997385,
#                                                         rmse: 0.38355530129226495, st.error:  0.0037014744031833415
# Adding Hamming 3 (Pubchem2d)... alpha = 0.007263157894736842
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.007473684210526316
# Start CV...
# New best params found! alpha:0.007473684210526316, k:1, leaf:100,
#                                                         acc:  0.8533862061260056, st.error:  0.0016382632626613174,
#                                                         rmse: 0.3828779750003438, st.error:  0.0021360087564535253
# Adding Hamming 3 (Pubchem2d)... alpha = 0.00768421052631579
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.007894736842105263
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.008105263157894737
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.00831578947368421
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.008526315789473684
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.008736842105263157
# Start CV...
# New best params found! alpha:0.008736842105263157, k:1, leaf:10,
#                                                         acc:  0.853497548988928, st.error:  0.0021555576338391494,
#                                                         rmse: 0.38271515292124947, st.error:  0.0028090361130063803
# Adding Hamming 3 (Pubchem2d)... alpha = 0.008947368421052631
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.009157894736842106
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.00936842105263158
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.009578947368421053
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.009789473684210527
# Start CV...
# Adding Hamming 3 (Pubchem2d)... alpha = 0.01
# Start CV...
# Thu Sep 10 20:09:36 2020

# %% [markdown]
# ## Final model -- BINARY

# %%
y = np.append(y_train,y_test)

del X_train, X_test, y_train, y_test

a_ham = 0.008620689655172414
a_pub = 0.008736842105263157
best_k = 1
best_leaf = 10

print('Basic Matrix...', ctime())
dist_matr = basic_matrix(X_try, categorical, non_categorical, a_ham)
print('Adding pubchem2d', ctime())
dist_matr += a_pub * pubchem2d_matrix(X_try)
dist_matr = pd.DataFrame(dist_matr)
print(ctime())
# Out:
# Basic Matrix... Fri Sep 11 09:28:15 2020
# Adding pubchem2d Fri Sep 11 09:53:22 2020
# Fri Sep 11 10:17:16 2020

# %%
kf = KFold(n_splits=5, shuffle=True, random_state = 5645)
accs = []
rmse = []
auc = []
for train_index, test_index in kf.split(dist_matr):

    X_train = dist_matr.iloc[train_index, train_index]
    X_test = dist_matr.iloc[test_index, train_index]
    y_train = y[train_index]
    y_test = y[test_index]

    neigh = KNeighborsClassifier(metric = 'precomputed',
                                 n_neighbors=best_k, n_jobs=-2,
                                 leaf_size=best_leaf)
    neigh.fit(X_train, y_train.ravel())
    y_pred = neigh.predict(X_test)
    
    accs.append(accuracy_score(y_test, y_pred))
    rmse.append(sqrt(mean_squared_error(y_test, y_pred)))
    auc.append(roc_auc_score(y_test, y_pred))
    
    del X_train, X_test, y_train, y_test
    
avg_acc = np.mean(accs)
se_acc = sem(accs)

avg_rmse = np.mean(rmse)
se_rmse = sem(rmse)

avg_auc = np.mean(auc)
se_auc = sem(auc)

print(ctime(), '\n')
print('''Accuracy: {}, se: {}
RMSE:     {}, se: {}
AUC:      {}, se: {}'''.format(avg_acc, se_acc, avg_rmse, se_rmse, avg_auc, se_auc))
# Out:
# Fri Sep 11 12:17:16 2020
#
# Accuracy: 0.8610594581695803, se: 0.001453875491295029
# RMSE:     0.37272693346224806, se: 0.0019477488447283864
# AUC:      0.8521153519758673, se: 0.0017759533977454501

# %% [markdown]
# # CHANGING CATEGORICAL VARIABLES

# %%
categorical = ['ring_number', 'tripleBond', 'obs_duration_mean', 'doubleBond', 'alone_atom_number', 'oh_count',
               
               'class', 'tax_order', 'family', 'genus', "species", 'control_type', 'media_type',
               'application_freq_unit',"exposure_type", "conc1_type"]

non_categorical =[ 'atom_number', 'bonds_number', 'Mol', 'MorganDensity', 'LogP']

y = np.append(y_train,y_test)

del X_train, X_test, y_train, y_test

a_ham = 0.008620689655172414
a_pub = 0.008736842105263157
best_k = 1
best_leaf = 10

print('Basic Matrix...', ctime())
dist_matr = basic_matrix(X_try, categorical, non_categorical, a_ham)
print('Adding pubchem2d', ctime())
dist_matr += a_pub * pubchem2d_matrix(X_try)
dist_matr = pd.DataFrame(dist_matr)
print(ctime())
# Out:
# Basic Matrix... Fri Sep 11 12:33:00 2020
# Adding pubchem2d Fri Sep 11 13:12:42 2020
# Fri Sep 11 13:40:18 2020

# %%
print(ctime())
kf = KFold(n_splits=5, shuffle=True, random_state = 5645)
accs = []
rmse = []
auc = []
for train_index, test_index in kf.split(dist_matr):

    X_train = dist_matr.iloc[train_index, train_index]
    X_test = dist_matr.iloc[test_index, train_index]
    y_train = y[train_index]
    y_test = y[test_index]

    neigh = KNeighborsClassifier(metric = 'precomputed',
                                 n_neighbors=best_k, n_jobs=-2,
                                 leaf_size=best_leaf)
    neigh.fit(X_train, y_train.ravel())
    y_pred = neigh.predict(X_test)
    
    accs.append(accuracy_score(y_test, y_pred))
    rmse.append(sqrt(mean_squared_error(y_test, y_pred)))
    auc.append(roc_auc_score(y_test, y_pred))
    
    del X_train, X_test, y_train, y_test
    
avg_acc = np.mean(accs)
se_acc = sem(accs)

avg_rmse = np.mean(rmse)
se_rmse = sem(rmse)

avg_auc = np.mean(auc)
se_auc = sem(auc)

print(ctime(), '\n')
print('''Accuracy: {}, se: {}
RMSE:     {}, se: {}
AUC:      {}, se: {}'''.format(avg_acc, se_acc, avg_rmse, se_rmse, avg_auc, se_auc))
# Out:
# Fri Sep 11 13:46:30 2020
# Fri Sep 11 15:28:52 2020
#
# Accuracy: 0.9107873636952324, se: 0.0016185189312741134
# RMSE:     0.29863626989204634, se: 0.0026932605579760697
# AUC:      0.9045684395646552, se: 0.0014456097816304332

# %% [markdown]
# # Moving obs_duration_mean from categorical to non categorical

# %%
categorical = ['ring_number', 'tripleBond', 'doubleBond', 'alone_atom_number', 'oh_count',
               
               'class', 'tax_order', 'family', 'genus', "species", 'control_type', 'media_type',
               'application_freq_unit',"exposure_type", "conc1_type"]

non_categorical =[ 'atom_number', 'bonds_number', 'Mol', 'MorganDensity', 'LogP', 'obs_duration_mean']

y = np.append(y_train,y_test)

del X_train, X_test, y_train, y_test

a_ham = 0.008620689655172414
a_pub = 0.008736842105263157
best_k = 1
best_leaf = 10

print('Basic Matrix...', ctime())
dist_matr = basic_matrix(X_try, categorical, non_categorical, a_ham)
print('Adding pubchem2d', ctime())
dist_matr += a_pub * pubchem2d_matrix(X_try)
dist_matr = pd.DataFrame(dist_matr)
print(ctime())
# Out:
# Basic Matrix... Sun Sep 13 17:35:44 2020
# Adding pubchem2d Sun Sep 13 17:38:52 2020
# Sun Sep 13 17:52:37 2020

# %%
print(ctime())
kf = KFold(n_splits=5, shuffle=True, random_state = 5645)
accs = []
rmse = []
auc = []
for train_index, test_index in kf.split(dist_matr):

    X_train = dist_matr.iloc[train_index, train_index]
    X_test = dist_matr.iloc[test_index, train_index]
    y_train = y[train_index]
    y_test = y[test_index]

    neigh = KNeighborsClassifier(metric = 'precomputed',
                                 n_neighbors=best_k, n_jobs=-2,
                                 leaf_size=best_leaf)
    neigh.fit(X_train, y_train.ravel())
    y_pred = neigh.predict(X_test)
    
    accs.append(accuracy_score(y_test, y_pred))
    rmse.append(sqrt(mean_squared_error(y_test, y_pred)))
    auc.append(roc_auc_score(y_test, y_pred))
    
    del X_train, X_test, y_train, y_test
    
avg_acc = np.mean(accs)
se_acc = sem(accs)

avg_rmse = np.mean(rmse)
se_rmse = sem(rmse)

avg_auc = np.mean(auc)
se_auc = sem(auc)

print(ctime(), '\n')
print('''Accuracy: {}, se: {}
RMSE:     {}, se: {}
AUC:      {}, se: {}'''.format(avg_acc, se_acc, avg_rmse, se_rmse, avg_auc, se_auc))
# Out:
# Sun Sep 13 17:59:30 2020
# Sun Sep 13 18:06:47 2020
#
# Accuracy: 0.8604262624980361, se: 0.0016865521320462175
# RMSE:     0.37356845626223895, se: 0.002255326351751561
# AUC:      0.8515386950848172, se: 0.0018082567850603412

# %% [markdown]
# # Moving discrete numerical variable to non categorical except for obs_duration_mean

# %%
categorical = ['class', 'tax_order', 'family', 'genus', "species", 'control_type', 'media_type',
               'application_freq_unit',"exposure_type", "conc1_type", 'obs_duration_mean']

non_categorical =['ring_number', 'tripleBond', 'doubleBond', 'alone_atom_number', 'oh_count',
                  'atom_number', 'bonds_number', 'Mol', 'MorganDensity', 'LogP']

y = np.append(y_train,y_test)

del X_train, X_test, y_train, y_test

a_ham = 0.008620689655172414
a_pub = 0.008736842105263157
best_k = 1
best_leaf = 10

print('Basic Matrix...', ctime())
dist_matr = basic_matrix(X_try, categorical, non_categorical, a_ham)
print('Adding pubchem2d', ctime())
dist_matr += a_pub * pubchem2d_matrix(X_try)
dist_matr = pd.DataFrame(dist_matr)
print(ctime())
# Out:
# Basic Matrix... Sun Sep 13 18:13:40 2020
# Adding pubchem2d Sun Sep 13 18:16:33 2020
# Sun Sep 13 18:34:21 2020

# %%
print(ctime())
kf = KFold(n_splits=5, shuffle=True, random_state = 5645)
accs = []
rmse = []
auc = []
for train_index, test_index in kf.split(dist_matr):

    X_train = dist_matr.iloc[train_index, train_index]
    X_test = dist_matr.iloc[test_index, train_index]
    y_train = y[train_index]
    y_test = y[test_index]

    neigh = KNeighborsClassifier(metric = 'precomputed',
                                 n_neighbors=best_k, n_jobs=-2,
                                 leaf_size=best_leaf)
    neigh.fit(X_train, y_train.ravel())
    y_pred = neigh.predict(X_test)
    
    accs.append(accuracy_score(y_test, y_pred))
    rmse.append(sqrt(mean_squared_error(y_test, y_pred)))
    auc.append(roc_auc_score(y_test, y_pred))
    
    del X_train, X_test, y_train, y_test
    
avg_acc = np.mean(accs)
se_acc = sem(accs)

avg_rmse = np.mean(rmse)
se_rmse = sem(rmse)

avg_auc = np.mean(auc)
se_auc = sem(auc)

print(ctime(), '\n')
print('''Accuracy: {}, se: {}
RMSE:     {}, se: {}
AUC:      {}, se: {}'''.format(avg_acc, se_acc, avg_rmse, se_rmse, avg_auc, se_auc))
# Out:
# Sun Sep 13 18:34:39 2020
# Sun Sep 13 18:40:42 2020
#
# Accuracy: 0.9105265658811724, se: 0.0016069239189876142
# RMSE:     0.29907298001784177, se: 0.00268266388479646
# AUC:      0.9041507029090183, se: 0.001539848447870826

# %% [markdown]
# # MULTICLASS
